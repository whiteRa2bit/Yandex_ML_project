# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Downloading data

# %%
train_file = open("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/train.txt","r")
train = train_file.read()

# %%
train = train.split('\n')
train = train[:-1]
print("Examples in test dataset:", len(train))
x_train = [data_example.split(' ')[0] for data_example in train]
y_train = [data_example.split(' ')[1] for data_example in train]
# Out:
# Examples in test dataset: 83194

# %%
print("Examples in x_train = ", len(x_train))
print("Examples in y_train = ", len(y_train))
print(x_train[:5])
print
print(y_train[:5])
# Out:
# Examples in x_train =  83194
# Examples in y_train =  83194
# ['LEMIEUX', 'MINDING', 'STRIPED', 'KEN', 'CONFERENCE']
# ['L_AH_M_Y_UW', 'M_AY_N_D_IH_NG', 'S_T_R_AY_P_T', 'K_EH_N', 'K_AA_N_F_ER_AH_N_S']

# %%
print("Longest word in x_train -", max(x_train, key=len), "with len =", len(max(x_train, key=len)))
print("Longest word in y_train -", max(y_train, key=len), "with len =", len(max(y_train, key=len)))
# Out:
# Longest word in x_train - SUPERCALIFRAGILISTICEXPIALIDOCIOUS with len = 34
# Longest word in y_train - S_UW_P_ER_K_AE_L_AH_F_R_AE_JH_AH_L_IH_S_T_IH_K_EH_K_S_P_IY_AE_L_AH_D_OW_SH_AH_S with len = 79

# %% [markdown]
# ### First model architecture:
# Represent each char as one-hot, use seq2seq without attention

# %% [markdown]
# ### Second model architecture:
# Represent each char as embedding, use seq2seq without attention

# %% [markdown]
# ### Third model architecture:
# Represent each char as embedding, use seq2seq with attention

# %% [markdown]
# ### EXTRA Improvements:
# Train biderectional rnn

# %% [markdown]
# ### Preprocessing

# %%
SOS_token = 0
EOS_token = 1
MAX_LENGTH = 100

class Vocab:
    def __init__(self):
        self.char2idx = {'s': 0, 'e': 1}
        self.idx2char = {0: 's', 1: 'e'}
        self.n_words = 2
    
    def addWord(self, word):
        for char in word:
            self.addChar(char)
            
    def addChar(self, char):
        if char not in self.char2idx:
            self.char2idx[char] = self.n_words
            self.idx2char[self.n_words] = char
            self.n_words += 1
        
    def tokenize(self, sequence):
        return [self.char2idx[sym] for sym in sequence]
    
    def detokenize(self, sequence):
        return ''.join([self.idx2char[num] for num in sequence])

# %%
def readLang(x_train, y_train, reverse=False):
    input_lang = Vocab()
    output_lang = Vocab()
    
    pairs = []
    for word in x_train:
        input_lang.addWord(word)
    for word in y_train:
        output_lang.addWord(word)
        
    for i in range(len(x_train)):
         pairs.append([x_train[i], y_train[i]])
                       
    return input_lang, output_lang, pairs

# %%
input_lang, output_lang, pairs = readLang(x_train, y_train)

# %%
print(pairs[:10])
# Out:
# [['LEMIEUX', 'L_AH_M_Y_UW'], ['MINDING', 'M_AY_N_D_IH_NG'], ['STRIPED', 'S_T_R_AY_P_T'], ['KEN', 'K_EH_N'], ['CONFERENCE', 'K_AA_N_F_ER_AH_N_S'], ['IMMOLATE', 'IH_M_AH_L_EY_T'], ['TRANSGRESS', 'T_R_AE_N_Z_G_R_EH_S'], ['RABBLE', 'R_AE_B_AH_L'], ['AIRSHARE', 'EH_R_SH_EH_R'], ['INTOLERANCE', 'IH_N_T_AA_L_ER_AH_N_S']]

# %%
print(random.choice(pairs))
# Out:
# ['UNREHEARSED', 'AH_N_R_IY_HH_ER_S_T']

# %%
for key,value in input_lang.char2idx.items():
    print(key, " - ", value)
# Out:
# s  -  0
# e  -  1
# L  -  2
# E  -  3
# M  -  4
# I  -  5
# U  -  6
# X  -  7
# N  -  8
# D  -  9
# G  -  10
# S  -  11
# T  -  12
# R  -  13
# P  -  14
# K  -  15
# C  -  16
# O  -  17
# F  -  18
# A  -  19
# B  -  20
# H  -  21
# V  -  22
# Y  -  23
# W  -  24
# J  -  25
# '  -  26
# Q  -  27
# Z  -  28
# -  -  29

# %%
for key,value in output_lang.char2idx.items():
    print(key, " - ", value)
# Out:
# s  -  0
# e  -  1
# L  -  2
# _  -  3
# A  -  4
# H  -  5
# M  -  6
# Y  -  7
# U  -  8
# W  -  9
# N  -  10
# D  -  11
# I  -  12
# G  -  13
# S  -  14
# T  -  15
# R  -  16
# P  -  17
# K  -  18
# E  -  19
# F  -  20
# Z  -  21
# B  -  22
# V  -  23
# O  -  24
# J  -  25
# C  -  26

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
    class AttnDecoderRNN(nn.Module):
        def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
            super(AttnDecoderRNN, self).__init__()
            self.hidden_size = hidden_size
            self.output_size = output_size
            self.dropout_p = dropout_p
            self.max_length = max_length

            self.embedding = nn.Embedding(self.output_size, self.hidden_size)
            self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
            self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
            self.dropout = nn.Dropout(self.dropout_p)
            self.gru = nn.GRU(self.hidden_size, self.hidden_size)
            self.out = nn.Linear(self.hidden_size, self.output_size)

        def forward(self, input, hidden, encoder_outputs):
            embedded = self.embedding(input).view(1, 1, -1)
            embedded = self.dropout(embedded)

            attn_weights = F.softmax(
                self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
            attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                     encoder_outputs.unsqueeze(0))

            output = torch.cat((embedded[0], attn_applied[0]), 1)
            output = self.attn_combine(output).unsqueeze(0)

            output = F.relu(output)
            output, hidden = self.gru(output, hidden)

            output = F.log_softmax(self.out(output[0]), dim=1)
            return output, hidden, attn_weights

        def initHidden(self):
            return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Training

# %%
def indexesFromWord(vocab, word):
    return [vocab.char2idx[char] for char in word]

def tensorFromWord(vocab, word):
    indexes = indexesFromWord(vocab, word)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromWord(input_lang, pair[0])
    target_tensor = tensorFromWord(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromWord(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden= decoder(
                decoder_input, decoder_hidden)
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                #decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.idx2char[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]
    
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ''.join(output_words)
        print('<', output_sentence)
        print('')

# %%
def predict(encoder, decoder, x):
    y = []
    for i in range(len(x)):
        if i % 1000 == 0:
            print("Progress:", i, "/", len(x))
        output_words, _ = evaluate(encoder, decoder, x[i])
        output_sentence = ''.join(output_words)
        output_sentence = output_sentence
        y.append(output_sentence)
    print("Finished!!! ")
    return y

# %%
hidden_size = 32
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder1 = DecoderRNN(hidden_size, output_lang.n_words).to(device)

# %%
trainIters(encoder1, decoder1, 50000, print_every=1000)
# Out:
# 0m 14s (- 11m 35s) (1000 2%) 1.7444
# 0m 33s (- 13m 30s) (2000 4%) 1.6794
# 0m 51s (- 13m 21s) (3000 6%) 1.6463
# 1m 6s (- 12m 47s) (4000 8%) 1.5776
# 1m 20s (- 12m 6s) (5000 10%) 1.5463
# 1m 38s (- 12m 0s) (6000 12%) 1.5256
# 1m 48s (- 11m 9s) (7000 14%) 1.4701
# 1m 59s (- 10m 28s) (8000 16%) 1.4387
# 2m 10s (- 9m 53s) (9000 18%) 1.3753
# 2m 20s (- 9m 23s) (10000 20%) 1.3618
# 2m 31s (- 8m 57s) (11000 22%) 1.3579
# 2m 42s (- 8m 33s) (12000 24%) 1.3008
# 2m 52s (- 8m 11s) (13000 26%) 1.2917
# 3m 3s (- 7m 51s) (14000 28%) 1.3158
# 3m 13s (- 7m 32s) (15000 30%) 1.2875
# 3m 25s (- 7m 15s) (16000 32%) 1.2962
# 3m 36s (- 6m 59s) (17000 34%) 1.2716
# 3m 46s (- 6m 42s) (18000 36%) 1.3019
# 3m 57s (- 6m 26s) (19000 38%) 1.3005
# 4m 8s (- 6m 12s) (20000 40%) 1.2812
# 4m 18s (- 5m 56s) (21000 42%) 1.2187
# 4m 29s (- 5m 42s) (22000 44%) 1.2177
# 4m 40s (- 5m 28s) (23000 46%) 1.2274
# 4m 50s (- 5m 15s) (24000 48%) 1.2546
# 5m 1s (- 5m 1s) (25000 50%) 1.1979
# 5m 12s (- 4m 48s) (26000 52%) 1.2345
# 5m 23s (- 4m 35s) (27000 54%) 1.2293
# 5m 34s (- 4m 23s) (28000 56%) 1.1949
# 5m 45s (- 4m 10s) (29000 57%) 1.1861
# 5m 56s (- 3m 57s) (30000 60%) 1.1778
# 6m 7s (- 3m 44s) (31000 62%) 1.1961
# 6m 18s (- 3m 32s) (32000 64%) 1.1810
# 6m 28s (- 3m 19s) (33000 66%) 1.1928
# 6m 38s (- 3m 7s) (34000 68%) 1.1978
# 6m 49s (- 2m 55s) (35000 70%) 1.1713
# 7m 0s (- 2m 43s) (36000 72%) 1.1754
# 7m 11s (- 2m 31s) (37000 74%) 1.1782
# 7m 22s (- 2m 19s) (38000 76%) 1.1658
# 7m 36s (- 2m 8s) (39000 78%) 1.1336
# 7m 47s (- 1m 56s) (40000 80%) 1.1347
# 7m 58s (- 1m 44s) (41000 82%) 1.1715
# 8m 8s (- 1m 33s) (42000 84%) 1.1700
# 8m 19s (- 1m 21s) (43000 86%) 1.1374
# 8m 30s (- 1m 9s) (44000 88%) 1.1523
# 8m 43s (- 0m 58s) (45000 90%) 1.1373
# 8m 57s (- 0m 46s) (46000 92%) 1.1204
# 9m 17s (- 0m 35s) (47000 94%) 1.1331
# 9m 36s (- 0m 24s) (48000 96%) 1.1009
# 9m 49s (- 0m 12s) (49000 98%) 1.1251
# 10m 7s (- 0m 0s) (50000 100%) 1.1027

# %%
path = "/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/Models/"
torch.save(encoder1.state_dict(), path + "encoder_baseline_no_attn_hd=32")
torch.save(decoder1.state_dict(), path + "decoder_baseline_no_attn_hd=32")

# %%
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
encoder1.load_state_dict(torch.load(path + "encoder_baseline"))
encoder1.eval()

attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
attn_decoder1.load_state_dict(torch.load(path + "decoder_baseline"))
attn_decoder1.eval()
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(27, 256)
#   (attn): Linear(in_features=512, out_features=100, bias=True)
#   (attn_combine): Linear(in_features=512, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1)
#   (gru): GRU(256, 256)
#   (out): Linear(in_features=256, out_features=27, bias=True)
# )

# %% [markdown]
# #### Postprocessing:
# trim extra '_' symbols

# %%
predicted = predict(encoder1, decoder1, x_train[:5000])
# Out:
# Progress: 0 / 5000
# Progress: 1000 / 5000
# Progress: 2000 / 5000
# Progress: 3000 / 5000
# Progress: 4000 / 5000
# Finished!!!

# %%
count = 0
for i in range(len(predicted)):
    if y_train[i] == predicted[i]:
        print("+++++++++")
    else:
        print("---------")
        print("Phonemes in original word:", y_train[i].count('_') + 1)
        print("Phonemse in predicted word:", predicted[i].count('_') + 1)
    print("Word:", x_train[i])
    print("Original:", y_train[i])
    print("Predict:", predicted[i])
    print()
    if y_train[i] == predicted[i]:
        count += 1
# Out:
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 9
# Word: LEMIEUX
# Original: L_AH_M_Y_UW
# Predict: L_AH_M_AH_N_I__Y_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MINDING
# Original: M_AY_N_D_IH_NG
# Predict: M_IH_N_D_IH_NG
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: STRIPED
# Original: S_T_R_AY_P_T
# Predict: S_L_IY_R_AH_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: KEN
# Original: K_EH_N
# Predict: K_EH_N_IY
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 13
# Word: CONFERENCE
# Original: K_AA_N_F_ER_AH_N_S
# Predict: K_AH_N_D_AH_N_______
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: IMMOLATE
# Original: IH_M_AH_L_EY_T
# Predict: IH_M_P_AH_L_A__N__
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: TRANSGRESS
# Original: T_R_AE_N_Z_G_R_EH_S
# Predict: T_R_EH_N_S_ER_T_S_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: RABBLE
# Original: R_AE_B_AH_L
# Predict: R_AE_P_AH_L
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 9
# Word: AIRSHARE
# Original: EH_R_SH_EH_R
# Predict: AE_R_T_ER_R____
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 13
# Word: INTOLERANCE
# Original: IH_N_T_AA_L_ER_AH_N_S
# Predict: IH_N_T_S_T_AH_L_T_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: ILVA
# Original: IH_L_V_AH
# Predict: IH_L_AH_L_I
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: RYGEL
# Original: R_IH_G_EH_L
# Predict: R_AY_F_AH_L
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: MARLETTE
# Original: M_AA_R_L_EH_T
# Predict: M_AA_R_T_IH_S_T_S_AH_L
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: DILDO
# Original: D_IH_L_D_OW
# Predict: D_IH_M_P_L_IH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: ORELIA
# Original: AO_R_EH_L_IY_AH
# Predict: AO_R_L_IH_S_IY_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: MCNISH
# Original: M_AH_K_N_IH_SH
# Predict: M_AH_N_IH_S_IH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: FURBISHED
# Original: F_ER_B_IH_SH_T
# Predict: F_AO_R_AH_B_ER_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: COMFED
# Original: K_AA_M_F_EH_D
# Predict: K_AH_M_P_AH
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 16
# Word: WALKENHORST
# Original: W_AO_K_AH_N_HH_AO_R_S_T
# Predict: W_AH_N_S_A___________
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: MILLIRONS
# Original: M_IH_L_ER_OW_N_Z
# Predict: M_EH_L_AH_L_IH_N_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: JERE
# Original: JH_EH_R_IY
# Predict: JH_ER_R_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: LIVAN'S
# Original: L_IY_V_AA_N_Z
# Predict: L_IH_M_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: PREVIEW
# Original: P_R_IY_V_Y_UW
# Predict: P_R_IH_S_IY_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: GRAYING
# Original: G_R_EY_IH_NG
# Predict: G_R_IH_N_IH_NG
#
# ---------
# Phonemes in original word: 2
# Phonemse in predicted word: 3
# Word: KU
# Original: K_UW
# Predict: K_OW_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: FREEHOLD
# Original: F_R_IY_HH_OW_L_D
# Predict: F_R_AH_F_AH_L
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: CONCA
# Original: K_AA_NG_K_AH
# Predict: K_AA_N_S_AH_N_N
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: TECK'S
# Original: T_EH_K_S
# Predict: T_AH_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: QUINTER
# Original: K_W_IH_N_T_ER
# Predict: K_AH_N_S_IH_N
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 40
# Word: CIRCUMSTANTIAL
# Original: S_ER_K_AH_M_S_T_AE_N_SH_AH_L
# Predict: K_AH_N_S_A__R_________________________________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: RYDELL
# Original: R_IH_D_AH_L
# Predict: R_IH_P_AH_L__
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: ROTOTILLER
# Original: R_OW_T_AH_T_IH_L_ER
# Predict: R_AH_T_S_T____L__
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 18
# Word: HAVINGTON'S
# Original: HH_AE_V_IH_NG_T_AH_N_Z
# Predict: HH_AE_M_AH_N_A____________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: DECALS
# Original: D_IY_K_AE_L_Z
# Predict: D_IH_S_AH_L_A__
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 14
# Word: DIBATTISTA
# Original: D_IH_B_AA_T_IY_S_T_AA
# Predict: D_IH_T_T_IH_T_S_T_AH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: RAVI'S
# Original: R_AA_V_IY_S
# Predict: R_IY_T_IY_AH
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 14
# Word: INTERCEPTING
# Original: IH_N_T_ER_S_EH_P_T_IH_NG
# Predict: IH_N_T_S_T_IH_S_T_IH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: FROMMELT
# Original: F_R_AA_M_IH_L_T
# Predict: F_R_AH_F_AH_M_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: ACCOMPANIED
# Original: AH_K_AH_M_P_AH_N_IY_D
# Predict: AH_M_F_AH_M_AH_N_AH_N_S_T_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 20
# Word: WHOLESALING
# Original: HH_OW_L_S_EY_L_IH_NG
# Predict: W_AH_L_AH_N_______________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: APHIDS
# Original: AE_F_IH_D_Z
# Predict: AE_M_P_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: LULLING
# Original: L_AH_L_IH_NG
# Predict: L_AH_F_IH_NG
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: HAIDA
# Original: HH_AY_D_AH
# Predict: HH_AE_M_A__T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: REDDITT
# Original: R_EH_D_IH_T
# Predict: R_IH_M_ER_R_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: WRONSKI
# Original: R_AA_N_S_K_IY
# Predict: W_AO_R_IH_N_S_IH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: AVERYL
# Original: AE_V_ER_IH_L
# Predict: AE_P_ER_R_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: PROPELLED
# Original: P_R_AH_P_EH_L_D
# Predict: P_R_UW_P_AH_L_A_
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: MAGRUDER
# Original: M_AH_G_R_UW_D_ER
# Predict: M_AA_G_R_ER_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: EMBEZZLES
# Original: IH_M_B_EH_Z_AH_L_Z
# Predict: EH_M_P_AH_L_A_____
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: MCNINCH
# Original: M_AH_K_N_IH_N_CH
# Predict: M_AH_N_S_IH_NG
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: DANDURAND
# Original: D_AE_N_D_ER_AH_N_D
# Predict: D_AE_N_D_A__M_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: REVIEWS
# Original: R_IY_V_Y_UW_Z
# Predict: R_IH_T_IH_S_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: B'RITH
# Original: B_R_IH_TH
# Predict: B_R_EH_T_IH_N
#
# ---------
# Phonemes in original word: 16
# Phonemse in predicted word: 21
# Word: UNCHARACTERISTICALLY
# Original: AH_N_K_EH_R_IH_K_T_ER_IH_S_T_IH_K_L_IY
# Predict: AH_N_S_IH_S_T_IH_L_IH_S_T_IH_S_T_S_AH_T_S_T_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: GANCARZ
# Original: G_AA_N_K_AA_R_Z
# Predict: G_AE_N_K_AH_N_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: RUTSTEIN
# Original: R_AH_T_S_T_AY_N
# Predict: R_AH_T_S_T_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: FRIDRICH
# Original: F_R_IH_D_R_IH_K
# Predict: F_R_AH_G_ER_R_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: KOZIK
# Original: K_OW_Z_IH_K
# Predict: K_AW_S_IY_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 10
# Word: EBBING
# Original: EH_B_IH_NG
# Predict: EH_M_A__N_____
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 11
# Word: BRIDGHAM
# Original: B_R_IH_JH_HH_AH_M
# Predict: B_R_AH_M_E__N____
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: ELLENBERGER
# Original: EH_L_AH_N_B_ER_G_ER
# Predict: AH_N_B_R_AH_F_ER_S_T_IH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 10
# Word: DISORDERS
# Original: D_IH_S_AO_R_D_ER_Z
# Predict: D_EH_K_S_ER_R_A__N_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 17
# Word: ATHLETICALLY
# Original: AE_TH_L_EH_T_IH_K_L_IY
# Predict: AE_T_L_IH_S_IH_S_T_IH_S_T_IH_S_T_S_IH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: KRAKOW
# Original: K_R_AA_K_AW
# Predict: K_R_AE_S_T_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SOLVIG
# Original: S_OW_L_V_IH_G
# Predict: S_AW_L_IH_L_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: SLURRED
# Original: S_L_ER_D
# Predict: S_L_AO_R_D
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: CONCOURSES
# Original: K_AA_N_K_AO_R_S_IH_Z
# Predict: K_AA_N_S_AH_N_T_S_T_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: BRUNNER
# Original: B_R_AH_N_ER
# Predict: B_R_AH_G_ER_R_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: SKINNER
# Original: S_K_IH_N_ER
# Predict: S_K_EH_N_IH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: VIOLIST'S
# Original: V_IY_OW_L_AH_S_T_S
# Predict: V_IH_L_IH_S_AH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 15
# Word: ENCEPHALITIS
# Original: EH_N_S_EH_F_AH_L_AY_T_AH_S
# Predict: IH_N_S_AH_L_IH_S_IH_S_AH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: MASEK
# Original: M_AA_S_EH_K
# Predict: M_AE_S_K
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 12
# Word: REINSTATED
# Original: R_IY_IH_N_S_T_EY_T_IH_D
# Predict: R_IH_S_AH_N_T_S_T_S_T_IH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: CHIAPAS'
# Original: CH_IY_AA_P_AH_Z
# Predict: CH_AH_P_IH_S_IH_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: AGERS
# Original: EY_JH_ER_Z
# Predict: AE_G_ER_Z
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 5
# Word: SCHIELE
# Original: SH_IY_L
# Predict: SH_AH_L_IY_IY
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 13
# Word: APOLOGIST
# Original: AH_P_AA_L_AH_JH_IH_S_T
# Predict: AE_P_AH_L_AH_N_______
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 5
# Word: ESME
# Original: EH_Z_M
# Predict: IH_M_A__N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: BREASTING
# Original: B_R_EH_S_T_IH_NG
# Predict: B_R_IH_S_IH_N____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: HERMON
# Original: HH_ER_M_AH_N
# Predict: HH_ER_M_A__N_D
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 15
# Word: INTERROGATIONS
# Original: IH_N_T_EH_R_AH_G_EY_SH_AH_N_Z
# Predict: IH_N_T_R__H_S_T_AH_S_T_S_T_IH_N
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: ZAN
# Original: Z_AE_N
# Predict: Z_EH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: FLAPPERS
# Original: F_L_AE_P_ER_Z
# Predict: F_L_EH_F_ER_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: GYMNASIUM
# Original: JH_IH_M_N_EY_Z_IY_AH_M
# Predict: JH_AH_M_AH_N_IH_NG_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: VIEWERS
# Original: V_Y_UW_ER_Z
# Predict: V_EH_R_IH_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: DIVERSIFIED
# Original: D_AY_V_ER_S_AH_F_AY_D
# Predict: D_IH_M_P_R_IH_S_ER_T_IH_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: ECKLAND
# Original: EH_K_L_AH_N_D
# Predict: AH_K_K_AH_L_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 17
# Word: KUOMINTANG
# Original: K_W_OW_M_IH_N_T_AE_NG
# Predict: K_AH_M_AH_N_N____N_______
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: CODRESCU
# Original: K_AH_D_R_EH_S_K_Y_UW
# Predict: K_AA_D_R_AH_R___
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: ADONIS
# Original: AH_D_AA_N_AH_S
# Predict: AE_M_AH_N______
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SEAMUS
# Original: SH_EY_M_AH_S
# Predict: S_IH_M_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: MARUYU
# Original: M_EH_R_UW_Y_UW
# Predict: M_AO_R_IY_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: PRUSSAK
# Original: P_R_AH_S_AH_K
# Predict: P_R_AO_S_T_AH_S_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: GUSSIED
# Original: G_AH_S_IY_D
# Predict: G_AH_G_IY_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 11
# Word: GIAMPAPA
# Original: JH_AA_M_P_AA_P_AA
# Predict: JH_AH_M_P_AH_M_AH_N_S_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: MARCOM
# Original: M_AA_R_K_AH_M
# Predict: M_AA_R_A__M_AH_N
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: TERM'S
# Original: T_ER_M_Z
# Predict: T_ER_D_ER
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: MAHANY
# Original: M_AE_HH_AH_N_IY
# Predict: M_AE_T_IH_NG
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 11
# Word: DISSOLVE
# Original: D_IH_Z_AA_L_V
# Predict: D_IH_S_AH_L_A_____
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: MAP
# Original: M_AE_P
# Predict: M_AE_P_AH
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: DISSENT
# Original: D_IH_S_EH_N_T
# Predict: D_IH_S_AH_N_N____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: CAPON
# Original: K_EY_P_AA_N
# Predict: K_AE_M_AH_L_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: PERCENTS
# Original: P_ER_S_EH_N_T_S
# Predict: P_ER_S_T_IH_N_N_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: NOKIA
# Original: N_OW_K_IY_AH
# Predict: N_AH_S_IH_S_IH_S
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 27
# Word: CROSS-POLLINATE
# Original: K_R_AO_S_P_AA_L_AH_N_EY_T
# Predict: K_R_AH_S_A__H_A___________________
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 12
# Word: DESAUTEL
# Original: D_EH_S_OW_T_AH_L
# Predict: D_IH_S_A__L_A_____
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: WANNEMACHER
# Original: W_AA_N_AH_M_AA_K_ER
# Predict: W_AH_N_D_A__N____
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 14
# Word: SHARPEST
# Original: SH_AA_R_P_AH_S_T
# Predict: SH_ER_R_A__________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 9
# Word: LOCKLAIR
# Original: L_AA_K_L_ER
# Predict: L_AH_K_S_A__L__
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: DISK
# Original: D_IH_S_K
# Predict: D_IH_S_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: PRAISING
# Original: P_R_EY_Z_IH_NG
# Predict: P_R_IH_S_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 12
# Word: MANCEBO
# Original: M_AA_N_CH_EH_B_OW
# Predict: M_AE_N_S_AH_N_A_____
#
# +++++++++
# Word: LOCA
# Original: L_OW_K_AH
# Predict: L_OW_K_AH
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 24
# Word: TUBERCULOSIS
# Original: T_AH_B_ER_K_Y_AH_L_OW_S_IH_S
# Predict: T_AH_B_R_AH_L_A_________________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: DITMARS
# Original: D_IH_T_M_ER_Z
# Predict: D_IH_M_ER_R_A___
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: DIVISIBLE
# Original: D_IH_V_IH_Z_AH_B_AH_L
# Predict: D_IH_V_AH_L_IH_S_IH_S
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 23
# Word: DELEGATIONS
# Original: D_EH_L_AH_G_EY_SH_AH_N_Z
# Predict: D_EH_L_IH_N__________________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: PLAINO
# Original: P_L_EY_N_OW
# Predict: P_L_AE_N_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 9
# Word: AVERITT
# Original: AE_V_ER_IH_T
# Predict: AE_T_ER_R_IH_S_T_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: ALONZO
# Original: AH_L_AA_N_Z_OW
# Predict: AH_L_AH_M_AH_N_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: MCKEEHAN
# Original: M_AH_K_IY_HH_AH_N
# Predict: M_AH_K_S_AH_N_IH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: ENFORCER
# Original: EH_N_F_AO_R_S_ER
# Predict: EH_N_D_R_AH_M_ER_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: APEC'S
# Original: EY_P_EH_K_S
# Predict: AE_M_P_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 24
# Word: LIBERTARIAN
# Original: L_IH_B_ER_T_EH_R_IY_AH_N
# Predict: T_EH_R_A__H__________________
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: HOW'RE
# Original: HH_AW_ER
# Predict: HH_AH_R_D
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: BONNET
# Original: B_AA_N_AH_T
# Predict: B_AO_N_T__H
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 17
# Word: REALIGNING
# Original: R_IY_AH_L_AY_N_IH_NG
# Predict: R_IH_S_AH_H_IH_N__________
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: MISSPOKEN
# Original: M_IH_S_S_P_OW_K_AH_N
# Predict: M_IH_K_AH_H_A__N____
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: KUZE
# Original: K_Y_UW_Z
# Predict: K_AW_S_I
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: KARCHER
# Original: K_AA_R_CH_ER
# Predict: K_AA_R_K_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: APPENDED
# Original: AH_P_EH_N_D_IH_D
# Predict: AE_M_P_AH_N_A
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 15
# Word: BACKDROPS
# Original: B_AE_K_D_R_AA_P_S
# Predict: B_AE_K_A_A__R_A_______
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: EDELSON
# Original: EH_D_IH_L_S_AH_N
# Predict: EH_M_P_AH_L_A__N__
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: NEWMONT'S
# Original: N_UW_M_AA_N_T_S
# Predict: N_AW_M_AH_N_N__
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: MELCHOR
# Original: M_EH_L_CH_ER
# Predict: M_AH_K_L_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SCHWARTZ
# Original: SH_W_AO_R_T_S
# Predict: SH_AO_R_T_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: WRESTLERS
# Original: R_EH_S_L_ER_Z
# Predict: L_AH_S_T_R_A__S_T_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: HOLLOWAY
# Original: HH_AA_L_OW_W_EY
# Predict: HH_AH_L_L_IH_S_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: SOFTEST
# Original: S_AO_F_T_AH_S_T
# Predict: S_AO_T_S_T_AH_S_T_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: HEATLEY
# Original: HH_IY_T_L_IY
# Predict: HH_IH_P_IH_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: FIATO
# Original: F_IY_AE_T_OW
# Predict: F_IH_S_A__T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: GLOD
# Original: G_L_AA_D
# Predict: G_L_AO_D_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: PROKOP
# Original: P_R_OW_K_AH_P
# Predict: P_R_AO_F_AH_S_AH_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: SHOCKS
# Original: SH_AA_K_S
# Predict: SH_AW_S_AH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: KEYNESIAN
# Original: K_EY_N_Z_IY_AH_N
# Predict: K_AH_N_IH_N_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: MARSHA
# Original: M_AA_R_SH_AH
# Predict: M_AA_R_T_AH_S_T
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: FARSIGHTED
# Original: F_AA_R_S_AY_T_AH_D
# Predict: F_AA_R_R__H_S_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: NARROWEST
# Original: N_EH_R_OW_AH_S_T
# Predict: N_AA_R_A_____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 9
# Word: SKURKA
# Original: S_K_ER_K_AA
# Predict: S_K_AO_R_T_R_A__
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: ALTOMARE
# Original: AA_L_T_OW_M_AA_R_IY
# Predict: AE_L_T_AH_R_T_S_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 11
# Word: STANKEVICH
# Original: S_T_AE_NG_K_AH_V_IH_CH
# Predict: S_T_EH_N_S_IH_S_IH_S_T_S
#
# +++++++++
# Word: BLECH'S
# Original: B_L_EH_K_S
# Predict: B_L_EH_K_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: DOUGANS
# Original: D_AW_G_AH_N
# Predict: D_AW_S_AH_N_N
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 27
# Word: HALLUCINATION
# Original: HH_AH_L_UW_S_AH_N_EY_SH_AH_N
# Predict: HH_AH_L_AH_N_AH_N____________________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SCANNING
# Original: S_K_AE_N_IH_NG
# Predict: S_T_AH_N_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 12
# Word: TEDESCO
# Original: T_EH_D_EH_S_K_OW
# Predict: T_EH_M_A__H______
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: GOLTZ
# Original: G_OW_L_T_S
# Predict: G_AO_L_T_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: BASCO
# Original: B_AA_S_K_OW
# Predict: B_AE_S_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: FATALISTS
# Original: F_EY_T_AH_L_IH_S_T_S
# Predict: F_AE_T_L_AH_S_T_S_T_S_AH_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 19
# Word: ULTIMATUM
# Original: AH_L_T_AH_M_EY_T_AH_M
# Predict: AH_L_A__H______________
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: BURRER
# Original: B_ER_ER
# Predict: B_AO_R_ER
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 21
# Word: AMBIDEXTROUS
# Original: AE_M_B_IH_D_EH_K_S_T_R_AH_S
# Predict: AE_M_P_ER_A________________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: OPEL'S
# Original: OW_P_AH_L_Z
# Predict: AW_B_AH_L_L
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: HEDGPETH
# Original: HH_EH_JH_P_IH_TH
# Predict: HH_AH_M_P_ER_S_T_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: SPINDLE
# Original: S_P_IH_N_D_AH_L
# Predict: S_P_EH_L_AH_N_S
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 23
# Word: TRIGLYCERIDES
# Original: T_R_AY_G_L_IH_S_ER_AY_D_Z
# Predict: L_R_IH_S_E__R________________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: FUSON
# Original: F_UW_S_AH_N
# Predict: F_AW_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: SECTION'S
# Original: S_EH_K_SH_AH_N_Z
# Predict: S_IH_S_T__H_S_T_IH_N
#
# +++++++++
# Word: HAFEY
# Original: HH_EY_F_IY
# Predict: HH_EY_F_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 18
# Word: RESIDENCIES
# Original: R_EH_Z_IH_D_EH_N_S_IY_Z
# Predict: R_IH_S_IH_N_____________
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: BEHM
# Original: B_EH_M
# Predict: B_EH_M_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: KROTKOV
# Original: K_R_AO_T_K_AO_V
# Predict: K_R_AW_S_T_A__S_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: CELOSIA
# Original: CH_EH_L_OW_S_IY_AH
# Predict: S_AH_L_IH_S_IH_S_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: PAPERWORK
# Original: P_EY_P_ER_W_ER_K
# Predict: P_AA_R_B_AH_R_D_ER
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: STRESSED
# Original: S_T_R_EH_S_T
# Predict: S_T_R_AH_S_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: PRIDDY
# Original: P_R_IH_D_IY
# Predict: P_R_IH_M_IY_R
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: COTY
# Original: K_OW_T_IY
# Predict: K_AW_T_IY_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 12
# Word: RECRUIT'S
# Original: R_IY_K_R_UW_T_S
# Predict: R_IH_S_ER_R_______
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: HANNAM
# Original: HH_AE_N_AH_M
# Predict: HH_AE_N_AH_N_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: BELLMON
# Original: B_EH_L_M_AH_N
# Predict: B_AH_L_M_AH_N_A
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: ENGLAND
# Original: IH_NG_G_L_AH_N_D
# Predict: EH_N_S_AH_M_AH_L
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: ENTICING
# Original: EH_N_T_AY_S_IH_NG
# Predict: EH_N_IH_S_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: DOBBIN
# Original: D_AA_B_IH_N
# Predict: D_UW_P_EH_N
#
# ---------
# Phonemes in original word: 2
# Phonemse in predicted word: 4
# Word: VAUGH
# Original: V_AO
# Predict: S_AW_S_A
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 9
# Word: KLEJNA
# Original: K_L_EY_N_ER
# Predict: K_L_AE_S_AH_N_N__
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: PUNTO
# Original: P_UW_N_T_OW
# Predict: P_AH_N_S_T_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 10
# Word: MANDATED
# Original: M_AE_N_D_EY_T_IH_D
# Predict: M_AE_N_D_AH_N____
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 10
# Word: FOGELSON
# Original: F_OW_G_AH_L_S_AH_N
# Predict: F_AA_K_AH_L_A__N__
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: HARTSOCK
# Original: HH_AA_R_T_S_AH_K
# Predict: HH_ER_T_A__S_T_AH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SAFLEY
# Original: S_AE_F_L_IY
# Predict: S_AE_L_IY_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: MONCADA
# Original: M_OW_N_K_AA_D_AH
# Predict: M_AA_N_S_AH_N_A___
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: MCWHIRT
# Original: M_AH_K_W_ER_T
# Predict: M_AH_K_S_ER_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: AMOSS
# Original: AH_M_AO_S
# Predict: AE_M_AH_S_AH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: POVICH'S
# Original: P_OW_V_IH_CH_IH_Z
# Predict: P_AW_S_I__Y_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: GRABAU
# Original: G_R_AE_B_AW
# Predict: G_R_AE_F_AH_M
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: DESMITH
# Original: D_EH_S_M_IH_TH
# Predict: D_IH_M_A__H_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: BOITANO
# Original: B_OY_T_AA_N_OW
# Predict: B_AW_T_S_T_AH_N_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 8
# Word: UNDO
# Original: AH_N_D_UW
# Predict: AH_N_D_A__N__
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: LAFLAM
# Original: L_AA_F_L_AE_M
# Predict: L_AE_F_AH_L
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: KOOP
# Original: K_UW_P
# Predict: K_AW_P_A
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: ROACHE
# Original: R_OW_CH
# Predict: R_OW_T_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 11
# Word: UNSOLVED
# Original: AH_N_S_AA_L_V_D
# Predict: AH_N_S_AH_L_A_____
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 31
# Word: CONDITIONAL
# Original: K_AH_N_D_IH_SH_AH_N_AH_L
# Predict: K_AH_N_A__H_A__N______________________
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: HARDIGREE
# Original: HH_AA_R_D_IH_G_R_IY
# Predict: HH_EH_R_ER_R_IY_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 14
# Word: BATHOLITH
# Original: B_AE_TH_AH_L_IH_TH
# Predict: B_AE_T_A__L_A_______
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: AMBROGIO
# Original: AE_M_B_R_OW_JH_IY_OW
# Predict: AE_M_B_R_AH_M_ER_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: GRBAVICA
# Original: G_ER_B_AA_V_IH_K_AH
# Predict: G_R_AH_F_AH_M_AH_N_T
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 14
# Word: TECHNOLOGIES
# Original: T_EH_K_N_AA_L_AH_JH_IY_Z
# Predict: T_IH_N_S_AH_L_IH_S_AH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 20
# Word: BRIDESMAIDS'
# Original: B_R_AY_D_Z_M_EY_D_Z
# Predict: B_R_AH_M_E__H___________N__
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: HEISBOURG
# Original: HH_AY_S_B_AO_R_G
# Predict: HH_AH_M_P_ER_R_AH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: EVADER
# Original: IH_V_EY_D_ER
# Predict: EH_M_P_ER_R_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: FOBEL'S
# Original: F_OW_B_AH_L_Z
# Predict: F_AW_B_A__L_
#
# ---------
# Phonemes in original word: 14
# Phonemse in predicted word: 37
# Word: CRIMINALIZATION
# Original: K_R_IH_M_AH_N_AH_L_AH_Z_EY_SH_AH_N
# Predict: K_R_IH_M_A__H_AH_N____________________________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 8
# Word: ANTIQUE
# Original: AE_N_T_IY_K
# Predict: AE_N_T_IH_S_T_IH_N
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 5
# Word: JUEL
# Original: JH_UW_L
# Predict: JH_AH_L_L_I
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: KULHANEK
# Original: K_AH_L_HH_AH_N_EH_K
# Predict: K_AH_L_AH_N____
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: PALFREY
# Original: P_AE_L_F_R_IY
# Predict: P_AE_L_ER_R_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 13
# Word: TURBEVILLE
# Original: T_ER_B_V_IH_L
# Predict: T_AH_B_L_IH_L_______
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: SOFAMOR
# Original: S_OW_F_AH_M_AO_R
# Predict: S_AA_F_AH_M_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: ULIN
# Original: Y_UW_L_IH_N
# Predict: AH_L_IH_N_
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: RECOVERED
# Original: R_AH_K_AH_V_ER_D
# Predict: R_IH_K_S_ER_T_S_T_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: DODGER
# Original: D_AA_JH_ER
# Predict: D_AH_D_ER_R_
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: MATASSA
# Original: M_AA_T_AA_S_AH
# Predict: M_AE_T_T_AH_S_T_AH_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 16
# Word: MITTELSTADT
# Original: M_IH_T_IH_L_SH_T_AE_T
# Predict: M_IH_S_T_A__R_T_S_T_S_T_S_AH_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: CLUES
# Original: K_L_UW_Z
# Predict: K_L_OW_S_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: OCCURRED
# Original: AH_K_ER_D
# Predict: AO_F_ER_R_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: REALIST
# Original: R_IY_AH_L_IH_S_T
# Predict: R_IH_S_AH_L_IH_S_T_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: DECENCY
# Original: D_IY_S_AH_N_S_IY
# Predict: D_IH_M_IH_N_I__N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: CATTANI
# Original: K_AA_T_AA_N_IY
# Predict: K_AE_T_IH_N_T_S_T_IH_N
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: CLOE
# Original: K_L_OW
# Predict: K_L_OW_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: JOKED
# Original: JH_OW_K_T
# Predict: JH_AH_G_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SOBON
# Original: S_OW_B_AO_N
# Predict: S_AW_B_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 13
# Word: AUTOCRATIC
# Original: AO_T_AH_K_R_AE_T_IH_K
# Predict: AW_T_T_R_AH_S_T_S_T_S_AH_T_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: GERALDS
# Original: JH_EH_R_AH_L_D_Z
# Predict: JH_ER_R_A__L___
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: DANER
# Original: D_EY_N_ER
# Predict: D_EH_N_D_ER
#
# ---------
# Phonemes in original word: 15
# Phonemse in predicted word: 17
# Word: INTELLECTUALISM
# Original: IH_N_T_EH_L_AH_K_CH_UW_AH_L_IH_Z_AH_M
# Predict: IH_N_T_S_AH_L_IH_S_T_S_AH_T_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: FORTMAN
# Original: F_AO_R_T_M_AH_N
# Predict: F_AO_R_A__M_D_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: NOBLER
# Original: N_OW_B_L_ER
# Predict: N_UW_B_ER_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: TAMPS
# Original: T_AE_M_P_S
# Predict: T_AE_M_A__L
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: GREED
# Original: G_R_IY_D
# Predict: G_R_IH_M_ER
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 14
# Word: SENTENCING
# Original: S_EH_N_T_AH_N_S_IH_NG
# Predict: S_IH_N_T_IH_N_N_______
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: DATAREX
# Original: D_EY_T_ER_EH_K_S
# Predict: D_EH_T_R_AH_S_T_ER_S_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: GERRYMANDER
# Original: JH_EH_R_IY_M_AE_N_D_ER
# Predict: JH_ER_R_A__M_ER_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HEIKEN
# Original: HH_AY_K_AH_N
# Predict: HH_IH_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: PYRAMID
# Original: P_IH_R_AH_M_IH_D
# Predict: P_ER_R_IH_M_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 11
# Word: NOURISHING
# Original: N_ER_IH_SH_IH_NG
# Predict: N_AH_R_IH_S_IH_N____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: PORDY
# Original: P_AO_R_D_IY
# Predict: P_AO_R_ER_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: COUSY
# Original: K_UW_Z_IY
# Predict: K_OW_Y_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: BYERLEIN
# Original: B_AY_R_L_AY_N
# Predict: B_EH_R_IH_S_IH_S_IY
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: WHIZ
# Original: W_IH_Z
# Predict: W_IH_S_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: RADANT
# Original: R_AA_D_AH_N_T
# Predict: R_AE_M_A__N_A__N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 14
# Word: ELDRIDA
# Original: EH_L_D_R_IY_D_AH
# Predict: EH_N_B_ER_R_A________
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 13
# Word: SEPARATENESS
# Original: S_EH_P_ER_AH_T_N_AH_S
# Predict: S_EH_B_R_AH_S_T_IH_N_S_T_IH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 15
# Word: PERSUASIVE
# Original: P_ER_S_W_EY_S_IH_V
# Predict: P_R_IH_S_IH_S_IH_S_T_IH_S_T_S_IH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 13
# Word: KILLINGBECK
# Original: K_IH_L_IH_NG_B_EH_K
# Predict: K_AH_L_AH_N_IH_S_IH_S_AH_S_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: RITACCO
# Original: R_IY_T_AA_K_OW
# Predict: R_IH_S_A__T_S_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: SENIOR
# Original: S_IY_N_Y_ER
# Predict: S_EH_N_S_IH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: OVERJOYED
# Original: OW_V_ER_JH_OY_D
# Predict: AW_P_ER_R_IH_S_IY_ER
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: LIKELIHOOD
# Original: L_AY_K_L_IY_HH_UH_D
# Predict: L_IH_K_S_AH_L_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: CIMINO
# Original: CH_IY_M_IY_N_OW
# Predict: K_IH_M_AH_N_N__
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: KOPPLE
# Original: K_AA_P_AH_L
# Predict: K_AH_P_AH_L
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: FLASHERS
# Original: F_L_AE_SH_ER_Z
# Predict: F_L_EH_K_ER
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: CHI'S
# Original: K_AY_Z
# Predict: CH_IY_S_IY
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: EXCELLENCY
# Original: EH_K_S_L_EH_N_S_IY
# Predict: IH_K_S_IH_L_IH_S_IH_S_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: PRITCHARD
# Original: P_R_IH_CH_ER_D
# Predict: P_R_AH_S_T_R_A__S_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: OSAKE
# Original: OW_S_AA_K_IY
# Predict: AW_S_AH_S_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MELLISH
# Original: M_EH_L_IH_SH
# Predict: M_EH_L_IY_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: KNUCKLE
# Original: N_AH_K_AH_L
# Predict: NK_AH_L_S_AH_L
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: SADDLEBAG
# Original: S_AE_D_AH_L_B_AE_G
# Predict: S_AE_P_AH_L_A_____
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: NABOBS
# Original: N_AE_B_AA_B_Z
# Predict: N_AA_B_AH_L
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: CAYSON
# Original: K_EY_S_AH_N
# Predict: K_AE_S_AH_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: BETRAYS
# Original: B_IH_T_R_EY_Z
# Predict: B_EH_R_IH_S_IH_S_T
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 17
# Word: QUALITATIVELY
# Original: K_W_AA_L_AH_T_EY_T_IH_V_L_IY
# Predict: K_AH_L_IH_S_IH_S_T_IH_S_T_IH_S_T_S_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: FREEWAYS
# Original: F_R_IY_W_EY_Z
# Predict: F_R_AY_S_IY_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: HOLT
# Original: HH_OW_L_T
# Predict: HH_AO_L_T_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: APPLEBAUM
# Original: AE_P_AH_L_B_AW_M
# Predict: AE_P_AH_L_A__N__
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 15
# Word: UNADJUSTED
# Original: AH_N_AH_JH_AH_S_T_IH_D
# Predict: AH_N_A__H_A__N_______
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: JOSSELYN
# Original: JH_AA_S_IH_L_IH_N
# Predict: JH_AH_S_IH_S_IH_S_IH_S_T
#
# +++++++++
# Word: EYRIE
# Original: EH_R_IY
# Predict: EH_R_IY
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 11
# Word: STRZELECKI
# Original: S_T_R_EH_Z_IH_L_EH_T_S_K_IY
# Predict: S_L_IH_T_IH_S_IH_S_T_IH_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: LIBRARIAN
# Original: L_AY_B_R_EH_R_IY_AH_N
# Predict: T_EH_R_A__M_ER_IH_S_T_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: HORGAN
# Original: HH_AO_R_G_AH_N
# Predict: HH_AA_R_AH_M_D
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 13
# Word: HELPLESSNESS
# Original: HH_EH_L_P_L_AH_S_N_AH_S
# Predict: HH_AH_L_AH_M_AH_N_AH_S_AH_S_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: LARZELERE
# Original: L_ER_Z_EH_L_ER
# Predict: L_AA_R_R_IY_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: SCIULLI
# Original: S_IY_UW_L_IY
# Predict: S_IH_L_IH_L_I
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: FITNESS
# Original: F_IH_T_N_AH_S
# Predict: F_IH_S_T__N_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: PAYMER
# Original: P_EY_M_ER
# Predict: P_AE_D_ER_Z
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 17
# Word: EXPIRATORY
# Original: IH_K_S_P_AY_R_AH_T_AO_R_IY
# Predict: EH_K_S_IH_P_ER_IH_S_IH_S_T_IH_S_T_S_IH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 8
# Word: HIEBERT
# Original: HH_IY_B_ER_T
# Predict: HH_EH_B_R__R__
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: STRAM
# Original: S_T_R_AE_M
# Predict: S_T_R_AE_D
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: DISORDERLY
# Original: D_IH_S_AO_R_D_ER_L_IY
# Predict: D_IH_K_ER_R_IH_F_ER_S_IY_IH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: SQUASH
# Original: S_K_W_AA_SH
# Predict: S_K_AW_S_A__
#
# +++++++++
# Word: MELLIE
# Original: M_EH_L_IY
# Predict: M_EH_L_IY
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 19
# Word: CRASNIANSKI
# Original: K_R_AE_S_N_IY_AE_N_S_K_IY
# Predict: K_R_IH_S_IH_N____N_________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: LONGMORE
# Original: L_OW_NG_M_AO_R
# Predict: L_AA_N_D_A__N__
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 10
# Word: HILLENBURG
# Original: HH_IH_L_AH_N_B_ER_G
# Predict: HH_AH_L_A__H_M_AH_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: CAVIAR
# Original: K_AE_V_IY_AA_R
# Predict: K_AE_T_IH_R_____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: KOHNEN
# Original: K_OW_N_AH_N
# Predict: K_AO_N_AH_N_N
#
# ---------
# Phonemes in original word: 1
# Phonemse in predicted word: 3
# Word: I
# Original: AY
# Predict: IY_S_IY
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: KNOB
# Original: N_AA_B
# Predict: K_R_UW_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: MERCHANTS
# Original: M_ER_CH_AH_N_T_S
# Predict: M_AE_R_T_S_T_AH_N_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: LIVOTI
# Original: L_IY_V_OW_T_IY
# Predict: L_IH_V_IH_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: KUNKEL
# Original: K_AH_NG_K_AH_L
# Predict: K_AH_N_S_AH_L_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: BROWSERS
# Original: B_R_AW_Z_ER_Z
# Predict: B_R_AH_S_ER_R_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: WANGLER
# Original: W_AE_NG_G_L_ER
# Predict: W_AH_L_D_R__H_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: RICK
# Original: R_IH_K
# Predict: R_IH_K_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 16
# Word: MICROWAVE
# Original: M_AY_K_R_AH_W_EY_V
# Predict: M_AH_K_R_AH_S_T_A________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MIDPAC
# Original: M_IH_D_P_AE_K
# Predict: M_AH_M_P_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: HEILAND
# Original: HH_AY_L_AH_N_D
# Predict: HH_AH_L_AH_N_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MAZEL
# Original: M_AH_Z_AH_L
# Predict: M_AE_K_L_IY
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 20
# Word: DIONYSIUS
# Original: D_AY_AH_N_IH_S_IY_AH_S
# Predict: D_IH_N_IH_N_______________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 8
# Word: FLEURETTE
# Original: F_L_ER_EH_T
# Predict: F_L_AH_R_IH_S_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: TOMATOES
# Original: T_AH_M_EY_T_OW_Z
# Predict: T_AW_M_A__M_AH_N
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 15
# Word: EVENTUALITY
# Original: AH_V_EH_N_CH_UW_AE_L_IH_T_IY
# Predict: EH_V_IH_L_IH_S_IH_S_T_IH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: SHELLACKED
# Original: SH_EH_L_AE_K_D
# Predict: SH_AH_L_AH_L__
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: BEGUILED
# Original: B_IH_G_AY_L_D
# Predict: B_AH_F_AH_L_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 11
# Word: OVERPRODUCED
# Original: OW_V_ER_P_R_AH_D_UW_S_T
# Predict: AW_M_B_R_AH_F_ER_R_AH_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SOBIL'S
# Original: S_OW_B_AH_L_Z
# Predict: S_AW_B_AH_L_I
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: ANALYST
# Original: AE_N_AH_L_IH_S_T
# Predict: AE_N_S_AH_L_IH_S_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: OUTRIGGER
# Original: AW_T_R_IH_G_ER
# Predict: AW_T_ER_R_IH_S_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: ZALOUDEK
# Original: Z_AE_L_AW_D_IH_K
# Predict: F_AA_L_AH_M_AH
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CANCAN
# Original: K_AE_N_K_AE_N
# Predict: K_AE_N_S_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: BUILTIN
# Original: B_IH_L_T_IH_N
# Predict: B_AH_L_IH_S_IH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: OMNISCIENT
# Original: AA_M_N_IH_SH_AH_N_T
# Predict: AW_B_N_IH_N_IH_NG
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 12
# Word: TECTONIC
# Original: T_EH_K_T_AA_N_IH_K
# Predict: T_IH_S_T_IH_N______
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 18
# Word: POSTNATAL
# Original: P_OW_S_T_N_EY_T_AH_L
# Predict: P_AA_S_T_A_____________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: FARNES
# Original: F_AA_R_N_Z
# Predict: F_ER_R_AH_N
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: BAHRE
# Original: B_AA_R
# Predict: B_ER_T_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: ALLEGIANCE
# Original: AH_L_IY_JH_AH_N_S
# Predict: AH_L_IH_N_IH_S_IH_S_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 12
# Word: ADRIANCE
# Original: AA_D_R_IY_AH_N_S
# Predict: AE_M_ER_R_IH_N_I_____
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: BEEN
# Original: B_IH_N
# Predict: B_EH_N_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: LEMOINE
# Original: L_IH_M_OY_N
# Predict: L_EH_M_IH_N_I
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: FICHUS
# Original: F_IH_CH_AH_S
# Predict: F_IH_S_AH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: FELIX'S
# Original: F_IY_L_IH_K_S_IH_Z
# Predict: F_EH_L_IH_S_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: CLIFFORD'S
# Original: K_L_IH_F_ER_D_Z
# Predict: K_L_EH_G_R_AH_R_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: KOZLOFF
# Original: K_AA_Z_L_AO_F
# Predict: K_AA_K_F_AH_L_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: MACEWEN
# Original: M_AH_K_Y_UW_AA_N
# Predict: M_AH_S_IH_N__
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: LEFFERTS
# Original: L_EH_F_ER_T_S
# Predict: L_EH_F_ER_R_ER
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: BODKIN
# Original: B_AA_D_K_IH_N
# Predict: B_AW_M_IH_N__
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: IMPROV
# Original: IH_M_P_R_AA_V
# Predict: IH_M_P_R_AH_M_ER
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 16
# Word: KONDRACKI
# Original: K_AH_N_D_R_AA_T_S_K_IY
# Predict: K_AA_N_D_A__N_________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: SATURATE
# Original: S_AE_CH_ER_EY_T
# Predict: S_AA_T_R_AH_S_T_S_T_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: STRASBURGER
# Original: S_T_R_AE_S_B_ER_G_ER
# Predict: S_T_R_AE_S_T_R_A__S_T_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 15
# Word: METROPOL'S
# Original: M_EH_T_R_AH_P_OW_L_Z
# Predict: M_AH_B_R_AH_L_A________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: BAGEL
# Original: B_EY_G_AH_L
# Predict: B_AE_F_AH_L
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 16
# Word: MULTICOLOR
# Original: M_AH_L_T_IY_K_AH_L_ER
# Predict: M_AH_L_S_AH_L__________
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: MOBSTER'S
# Original: M_AA_B_S_T_ER_Z
# Predict: M_AO_T_ER_R_A____
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 17
# Word: HORSEPOWER
# Original: HH_AO_R_S_P_AW_ER
# Predict: HH_AH_R_A__H___________
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: RAWLS
# Original: R_AO_L_Z
# Predict: R_OW_L_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: SUDDARTH
# Original: S_AH_D_AA_R_TH
# Predict: S_AH_M_B_R_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: REMPEL
# Original: R_EH_M_P_AH_L
# ...
#
# ---------
# Phonemes in original word: 13
# Phonemse in predicted word: 29
# Word: METROPOLITAN'S
# Original: M_EH_T_R_AH_P_AA_L_AH_T_AH_N_Z
# Predict: M_EH_T_R_AH_S_A__H____________________
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 11
# Word: SLOVAKIAN
# Original: S_L_OW_V_AA_K_IY_AH_N
# Predict: S_L_AH_S_AH_N_____
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: EXTANT
# Original: EH_K_S_T_AH_N_T
# Predict: EH_S_T_AH_N_T_S_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: YONA
# Original: Y_OW_N_AH
# Predict: H_AH_N_A__N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: MEISSNER
# Original: M_AY_S_N_ER
# Predict: M_EH_N_S_ER_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: VANHORNE
# Original: V_AE_N_HH_AO_R_N
# Predict: V_AE_N_S_AH_N_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: BICEPS
# Original: B_AY_S_EH_P_S
# Predict: B_IH_S_AH_P_IH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 12
# Word: PENNSAUKEN
# Original: P_EH_N_S_AO_K_AH_N
# Predict: P_AH_N_S_AH_N_N____N_
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: MORENO
# Original: M_AO_R_IY_N_OW
# Predict: M_AO_R_AH_M_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: PISTOLE
# Original: P_IH_S_T_OW_L
# Predict: P_IH_S_T_AH_L_S_T_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SENIORS
# Original: S_IY_N_Y_ER_Z
# Predict: S_EH_N_S_IH_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: REBUILDER
# Original: R_IY_B_IH_L_D_ER
# Predict: R_IH_P_EH_R_IY_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: GARCIA
# Original: G_AA_R_S_IY_AH
# Predict: G_AA_R_IH_S_IH_N_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: SITKO
# Original: S_IH_T_K_OW
# Predict: S_IH_S_T___
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: BRUCK'S
# Original: B_R_AH_K_S
# Predict: B_R_AH_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: NOWLAND
# Original: N_AW_L_AH_N_D
# Predict: N_AO_F_AH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: DASCENZO
# Original: D_AA_S_CH_EH_N_Z_OW
# Predict: D_AE_S_AH_N_N_____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: STARRED
# Original: S_T_AA_R_D
# Predict: S_T_R_EH_D
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: GERM
# Original: JH_ER_M
# Predict: JH_ER_R_AH
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: ROYLE
# Original: R_OY_L
# Predict: R_UW_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HESIK
# Original: HH_EH_S_IH_K
# Predict: HH_AY_S_AH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 12
# Word: HORNBLOWER
# Original: HH_AO_R_N_B_L_OW_ER
# Predict: HH_AH_R_M_AA_R_A____L_A
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 13
# Word: STEINBORN
# Original: S_T_AY_N_B_AO_R_N
# Predict: S_T_EH_N_A__H______
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: PLEADINGS
# Original: P_L_IY_D_IH_NG_Z
# Predict: P_L_IH_M_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: ACKHOUSE
# Original: AE_K_HH_AW_S
# Predict: AE_K_S_AH_S_AH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: MCKIM
# Original: M_AH_K_IH_M
# Predict: M_AH_K_IH_N__
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: ANACKER
# Original: AE_N_AH_K_ER
# Predict: AE_N_S_AH_N_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: ULA
# Original: Y_UW_L_AH
# Predict: AH_L_A__L
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 19
# Word: CONFLAGRATION
# Original: K_AA_N_F_L_AH_G_R_EY_SH_AH_N
# Predict: K_AA_N_F_AH_M_AH_N_A__________
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: LIFE-CHANGING
# Original: L_AY_F_CH_EY_N_JH_IH_NG
# Predict: L_IH_F_IH_N_IH_NG_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: UGLIEST
# Original: AH_G_L_IY_AH_S_T
# Predict: AH_K_S_AH_L_IH_S_T_S_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: ISLAS
# Original: AY_L_AH_Z
# Predict: IH_K_L_AH_L
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: BAITS
# Original: B_EY_T_S
# Predict: B_AE_T_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: DYNEER
# Original: D_IH_N_IH_R
# Predict: D_IH_N_D_ER_R_I
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: NOSY
# Original: N_OW_Z_IY
# Predict: N_UW_Y_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: DEALY
# Original: D_IY_L_IY
# Predict: D_IH_L_IY_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HOLAN
# Original: HH_OW_L_AH_N
# Predict: HH_AA_L_AH_N
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 16
# Word: PROSECUTORS
# Original: P_R_AA_S_IH_K_Y_UW_T_ER_Z
# Predict: P_R_AH_S_T_A__________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: EDWARD
# Original: EH_D_W_ER_D
# Predict: EH_M_B_R_AH_R
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: FREDERIC
# Original: F_R_EH_D_R_IH_K
# Predict: F_R_IH_G_ER_R_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: PATCHING
# Original: P_AE_CH_IH_NG
# Predict: P_AE_T_IH_N_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CRISPY
# Original: K_R_IH_S_P_IY
# Predict: K_R_IH_P_IY_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: PLATTS
# Original: P_L_AE_T_S
# Predict: P_R_AE_S_T_S
#
# +++++++++
# Word: PENTZ
# Original: P_EH_N_T_S
# Predict: P_EH_N_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: COTTA
# Original: K_AA_T_AH
# Predict: K_AW_T_T_T_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: BLACKEST
# Original: B_L_AE_K_AH_S_T
# Predict: B_L_AE_K_S_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: LEPPLA
# Original: L_EH_P_L_AH
# Predict: L_AH_P_AH_L_I
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: IMPEACH
# Original: IH_M_P_IY_CH
# Predict: IH_M_P_IH_S_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 8
# Word: CHELETTE
# Original: SH_IH_L_EH_T
# Predict: CH_EH_L_IH_S_T_IH_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: TOYED
# Original: T_OY_D
# Predict: M_AY_D_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 14
# Word: LITHUANIA'S
# Original: L_IH_TH_AH_W_EY_N_IY_AH_Z
# Predict: T_R_AH_S_IH_S_IH_S_AH_N_T_S_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: KLOECKNER
# Original: K_L_OW_K_N_ER
# Predict: K_L_AH_N_S_ER_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: DARMAN'S
# Original: D_AA_R_M_AH_N_Z
# Predict: D_EH_R_M_AH_N
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: DORSCH
# Original: D_AO_R_SH
# Predict: D_AO_R_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: DIRCKS
# Original: D_ER_K_S
# Predict: D_EH_N_T_R_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: ENSCONCE
# Original: IH_N_S_K_AA_N_S
# Predict: EH_N_S_AH_N_S_T_IH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: JUDSEN
# Original: JH_AH_D_S_AH_N
# Predict: JH_AH_M_A__N__
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: COILING
# Original: K_OY_L_IH_NG
# Predict: K_AH_L_IH_S_IH_S
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 15
# Word: ANALYTICITY
# Original: AE_N_AH_L_AH_T_IH_S_AH_T_IY
# Predict: AE_N_S_IH_S_IH_S_IH_S_IH_S_T_S_IH_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: COMBED
# Original: K_OW_M_D
# Predict: K_AH_M_B_AH_T
#
# ---------
# Phonemes in original word: 14
# Phonemse in predicted word: 12
# Word: PROGNOSTICATED
# Original: P_R_AA_G_N_AA_S_T_AH_K_EY_T_IH_D
# Predict: F_R_AH_S_A__M_AH_N_T_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 10
# Word: TITANIC
# Original: T_AY_T_AE_N_IH_K
# Predict: T_IH_T_IH_N_____
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: MUTCH
# Original: M_AH_CH
# Predict: M_AW_T_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: NIES
# Original: N_AY_Z
# Predict: N_IY_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: DONOHO
# Original: D_AA_N_AH_HH_OW
# Predict: D_AH_N_S_AH_N_
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: FICHERA
# Original: F_IY_K_EH_R_AH
# Predict: F_IH_S_ER_R_____
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MILNER
# Original: M_IH_L_N_ER
# Predict: M_EH_L_ER_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: JOHNSTONE
# Original: JH_AA_N_S_T_OW_N
# Predict: JH_AH_N_S_AH_N_T_S_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: LOGOTHETIS
# Original: L_OW_G_OW_TH_EH_T_IH_S
# Predict: L_AO_R_S_AH_T_S_T_IH_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 5
# Word: KYL
# Original: K_AY_L
# Predict: K_AH_L_IY_I
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: MCKAIN
# Original: M_AH_K_EY_N
# Predict: M_AH_K_IH_N__
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 12
# Word: DISPROVED
# Original: D_IH_S_P_R_UW_V_D
# Predict: D_IH_M_P_R_AH_S_T_ER_S_T_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: AVERAGED
# Original: AE_V_R_IH_JH_D
# Predict: AE_M_ER_R_ER_R_IH_S_T
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: NULLIFYING
# Original: N_AH_L_AH_F_AY_IH_NG
# Predict: N_AH_F_IH_L_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: KRAFT
# Original: K_R_AE_F_T
# Predict: K_R_EH_F_AH_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 12
# Word: ROSINA
# Original: R_OW_Z_IY_N_AH
# Predict: R_AH_S_IH_N_______
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: HEIFERS
# Original: HH_EH_F_ER_Z
# Predict: HH_EH_F_ER_R_I
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: HIRED
# Original: HH_AY_ER_D
# Predict: HH_ER_D_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SHERTZER
# Original: SH_ER_T_Z_ER
# Predict: SH_ER_S_T_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: BUDER
# Original: B_Y_UW_D_ER
# Predict: B_AH_D_ER_R
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 18
# Word: TRANSFORMERS
# Original: T_R_AE_N_S_F_AO_R_M_ER_Z
# Predict: T_R_AE_K_A_AR_A___________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: BRAND'S
# Original: B_R_AE_N_D_Z
# Predict: B_AA_R_D_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HARIRI
# Original: HH_ER_IH_R_IY
# Predict: HH_ER_R_IY_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: DWORSKY
# Original: D_W_ER_S_K_IY
# Predict: D_AH_R_I__Y_IY
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 10
# Word: SPANDEX
# Original: S_P_AE_N_D_AH_K_S
# Predict: S_P_AH_N_M_AH_N_N__
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 13
# Word: MISSISSAUGA
# Original: M_IH_S_IH_S_AO_G_AH
# Predict: M_IH_S_AH_S_IH_S_AH_S_T_S_AH_N
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 19
# Word: GYROSCOPIC
# Original: JH_AY_R_AH_S_K_AA_P_IH_K
# Predict: G_AH_R_AH_H______________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: LENGEL
# Original: L_EH_NG_G_AH_L
# Predict: L_IH_K_L_IH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SARAH'S
# Original: S_EH_R_AH_Z
# Predict: S_AA_R_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: DONATE
# Original: D_OW_N_EY_T
# Predict: D_AH_N_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: SCIENCES
# Original: S_AY_AH_N_S_AH_Z
# Predict: S_IH_N_IH_S_IH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 17
# Word: INVESTOR'S
# Original: IH_N_V_EH_S_T_ER_Z
# Predict: IH_N_T_A_____________
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: TARGETED
# Original: T_AA_R_G_AH_T_IH_D
# Predict: T_R_EH_M_ER_R_IH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 11
# Word: RESEALABLE
# Original: R_IY_S_IY_L_AH_B_AH_L
# Predict: R_IH_S_AH_L_IH_S_AH_L_IH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: TATEHO'S
# Original: T_AH_T_EY_HH_OW_Z
# Predict: T_AE_T_T_AH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: DEFORE
# Original: D_IY_F_AO_R
# Predict: D_EH_F_ER_R_I
#
# ---------
# Phonemes in original word: 13
# Phonemse in predicted word: 24
# Word: SUPERCONDUCTORS
# Original: S_UW_P_ER_K_AH_N_D_AH_K_T_ER_Z
# Predict: S_AH_M_R_AH_M_A__R_A______________
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 20
# Word: JARUZELSKI
# Original: JH_EH_R_AH_Z_EH_L_S_K_IY
# Predict: JH_EH_R_AH_L_______________
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: STORE'S
# Original: S_T_AO_R_Z
# Predict: S_T_R_AW_T_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: PLENUM
# Original: P_L_EH_N_AH_M
# Predict: P_L_IH_NG_G_AH_N
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: TOOTE
# Original: T_UW_T
# Predict: T_AW_T_T
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: NIESS
# Original: N_IY_S
# Predict: N_IY_S_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: PADLOCK
# Original: P_AE_D_L_AA_K
# Predict: P_AE_P_L_AH_N_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: KVAMME
# Original: K_AH_V_AE_M
# Predict: K_M_AH_M_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: MAYTAG
# Original: M_EY_T_AE_G
# Predict: M_AE_T_S_T_IH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: COUSIN'S
# Original: K_AH_Z_AH_N_Z
# Predict: K_AW_S_IH_N__
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: BICHSEL
# Original: B_IH_K_S_AH_L
# Predict: B_IH_S_AH_L_I
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: LOVER
# Original: L_AH_V_ER
# Predict: L_A__M_ER_R
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 9
# Word: WORSTELL
# Original: W_ER_S_T_AH_L
# Predict: W_AO_R_T_S_T_AH_L_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: HOOTS
# Original: HH_UW_T_S
# Predict: HH_AW_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: CLOWES
# Original: K_L_AW_Z
# Predict: K_L_OW_T_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 11
# Word: JACQUELINE
# Original: JH_AE_K_W_AH_L_IH_N
# Predict: JH_IH_S_AH_L_IH_S_IH_S_T_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CANCUN
# Original: K_AE_NG_K_AH_N
# Predict: K_AE_N_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: NEUGEBAUER
# Original: N_UW_G_AH_B_AW_ER
# Predict: N_UW_P_ER_IY_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 13
# Word: PROSECUTOR
# Original: P_R_AA_S_IH_K_Y_UW_T_ER
# Predict: P_R_AH_S_T_A__R_T_S_T_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: STIEBEL
# Original: S_T_IY_B_AH_L
# Predict: S_T_EH_B_EH_L_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 17
# Word: FENSTERMAKER
# Original: F_EH_N_S_T_ER_M_EY_K_ER
# Predict: F_EH_N_S_AH_R_T__________
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: SIDDONS
# Original: S_IH_D_AH_N_Z
# Predict: S_IH_M_A__N__
#
# Accuracy = 0.0108

# %%
print("Accuracy =", count/len(predicted)*100, "%")
# Out:
# Accuracy = 1.08 %

# %%
print(encoder1.embedding.state_dict())
# Out:
# OrderedDict([('weight', tensor([[ 0.3416,  0.8906, -0.6003, -0.6623, -0.0357,  0.2689, -0.3708,  0.8050,
#          -0.4626,  0.4882,  0.1633, -0.7643,  1.0208,  1.2849, -2.0322,  0.2463,
#           1.0527,  0.4998, -0.1019, -0.1499, -0.4228, -0.5647,  1.0493, -1.1900,
#          -1.0473, -0.4658, -1.3904, -0.5163,  0.7928,  0.4784, -0.2442, -0.6459],
#         [ 0.8539,  0.4259,  1.3144,  0.1777, -0.4055, -0.9379, -0.2000, -0.0936,
#          -1.1721, -0.6530,  0.0709,  0.8879, -0.6945, -0.7656, -0.6797, -1.5676,
#          -0.6930,  1.3422,  0.8699, -1.4789, -0.0701, -0.8641, -0.9179, -0.9555,
#          -1.4709,  0.4562, -0.2894,  0.0567,  1.1333, -1.4671, -0.2503, -0.0854],
#         [-0.7532,  0.6797,  0.0049, -1.0169,  1.4035, -0.6706, -0.3079, -0.8551,
#          -0.0150, -1.8275, -0.3813, -0.8090, -0.4025, -0.6206,  0.2088, -0.1567,
#           0.6299, -0.3709,  0.0344,  0.6513,  0.1139,  0.1278, -0.6439, -0.4574,
#          -0.9845, -0.4232,  0.3642,  0.5281, -0.5869, -0.5567, -0.0698, -0.6065],
#         [ 0.2049,  1.0412,  0.3228, -0.1852, -0.7668,  2.2185,  0.3312,  0.0120,
#           0.5273, -0.1772, -0.3658, -0.4923,  0.4582, -0.1903,  1.7712, -1.1133,
#          -1.5219,  0.9615,  0.5827,  1.2460,  0.1252, -0.6832, -0.8812, -0.4516,
#           0.8293,  0.9879,  0.4347,  0.9393, -0.2280,  1.3487, -0.5906,  0.3795],
#         [-0.9189, -1.3346, -0.1938, -1.6853, -0.3124, -0.7246, -1.3498, -0.7357,
#          -1.6639,  0.2269,  2.1474, -0.6234, -2.1179,  0.2945, -0.7920, -0.4389,
#          -0.5669,  0.2212,  0.0912, -0.4978,  0.9672, -1.3832, -0.7281,  0.5322,
#           1.2108, -0.0944,  0.6185, -1.2571,  0.0192, -0.1608, -0.4981, -1.0495],
#         [-0.5971,  0.1117,  0.2016,  0.3175, -1.0681,  0.9426, -0.0912, -0.6972,
#           1.9755, -0.6321, -0.7622,  1.7140, -1.9483, -0.5005, -0.6952,  0.4164,
#          -0.5643,  0.7487, -0.5207, -0.9173,  0.0047,  0.6879,  0.5352, -1.1055,
#          -1.2667,  0.4284, -0.6490, -0.6983,  0.8751,  0.6665, -0.5369, -1.3408],
#         [-1.0412,  0.8260,  0.1921, -1.1049,  0.0292,  1.3587, -0.3879, -0.2234,
#          -0.5098,  0.6669, -0.1146,  0.2056, -0.0272, -0.4915,  0.7549, -1.3230,
#          -0.7414, -1.5316,  1.0164, -0.1867, -1.7082,  1.7515, -0.7548, -0.5153,
#          -1.0700, -1.6749,  0.8601, -2.0711,  2.5491,  1.2528, -0.4962, -0.7468],
#         [ 0.5303, -0.3909, -2.9743, -0.0208,  0.0056, -0.9729, -0.1400, -0.5221,
#          -0.7330,  0.6160, -0.1272, -0.2182,  0.0922, -0.3760,  1.0409,  0.0339,
#          -0.4949,  0.9784, -0.2569,  0.7705, -0.5658,  0.5952,  0.5187, -0.6665,
#          -0.2563, -0.2226, -0.9141, -0.7733,  0.6434, -1.3322,  0.4527,  0.1351],
#         [ 0.0721,  0.0973,  0.1021, -1.6201, -0.3109, -0.2173,  0.7659, -0.6682,
#           0.4217, -0.2578,  0.4898, -0.2124, -0.0519, -0.6247, -0.4457, -0.7031,
#          -0.2458,  0.0764, -0.4527, -1.0083,  0.2127, -0.2041, -0.6461,  0.4745,
#          -1.2523,  0.6842, -0.7823, -0.3510, -0.8797, -0.3923, -0.4464,  0.7051],
#         [-0.5150,  1.7182,  0.7742,  0.4188, -2.6228, -0.2528, -0.3651, -1.5813,
#           0.9321,  0.9553,  1.0907, -0.8260,  1.1050, -0.0259,  0.4974,  0.5583,
#          -0.3135,  0.3775, -0.5167,  0.9137,  1.3475, -1.5888, -0.1215, -0.4582,
#          -0.1897, -0.3955,  0.9463, -1.1858,  1.2969, -1.2121, -1.1748, -0.1033],
#         [-0.5061, -0.2108, -1.8765,  0.7680,  1.1582,  0.2079, -0.7988,  0.9194,
#          -1.8764, -0.1747,  0.5016, -0.0460, -0.5594, -0.0917, -0.8482,  0.6023,
#          -2.0472,  0.0878,  0.5846, -0.1654,  0.0784,  0.9124,  0.2954, -0.2502,
#           0.6561,  1.1693, -0.1234, -0.4236,  0.7455, -0.1522, -0.0909, -0.6216],
#         [ 0.8688,  0.7122, -0.1101, -1.7243, -0.4945, -0.6137, -1.6760,  1.1850,
#          -0.5703,  0.2084,  1.6317,  1.3868,  0.0192,  0.2945, -0.9005, -0.9546,
#          -0.2005,  0.3580,  0.4555,  0.9683, -1.0729, -0.1636,  0.4035,  0.5890,
#          -0.9207,  0.0282,  0.0606,  1.3818, -0.4602,  0.2340,  0.5239,  0.9868],
#         [ 0.0205, -1.3012, -0.1538,  0.9818, -0.4930, -1.1113, -0.3371, -1.1178,
#          -0.9745, -0.5871,  0.1137, -0.1694, -0.0394, -0.7505,  0.3255,  1.1837,
#           0.5427,  0.6267,  0.4696, -0.6237,  0.1182,  0.1614,  0.2244, -0.2497,
#          -0.3698, -0.5970,  0.3229, -0.0877, -0.9959,  1.1925, -1.2071,  0.2422],
#         [ 0.3150,  0.1139, -0.2986,  0.4144,  0.0580,  0.8024,  1.3877, -0.7628,
#           0.1559,  0.3500, -0.1081,  0.0117, -0.1729, -0.0908, -1.0304,  0.5354,
#          -0.5727, -1.0183, -1.1288,  0.2155,  0.4426, -0.1876, -0.7932,  0.2275,
#           0.5852, -0.2472,  0.2633, -0.2316,  0.4544,  0.3262, -0.4611,  0.0030],
#         [ 0.0956,  1.8367, -0.6277, -0.8941, -0.8182, -1.4861, -0.3887, -0.2057,
#          -0.3131,  1.0583, -2.4924, -0.0924, -0.1197, -1.1432,  0.3953,  0.1229,
#          -1.4272,  0.1936, -0.7167,  0.2945,  1.7362, -0.3063,  0.7897, -0.1688,
#          -1.1709,  0.3315,  0.2778,  0.0084, -0.6491, -0.3499,  0.5107, -0.0225],
#         [-0.3808,  0.0092, -0.1827,  0.1152, -0.4678,  0.3727,  0.8697, -0.5011,
#          -0.1611, -0.9842,  0.3996,  2.0255,  0.7707,  0.3590,  0.4379,  1.5757,
#           0.2115, -1.6972,  0.8505,  0.0498,  2.3936,  0.9467,  0.8357,  1.1652,
#           1.1193,  0.1143,  0.9718, -0.7838, -0.3547, -1.3670, -0.4809, -0.9771],
#         [ 0.6546,  1.3316, -0.5086,  0.1312,  0.8081, -1.6733, -1.6448, -1.1643,
#          -0.8234,  0.9072,  1.7533,  2.6459,  0.4408,  0.9737,  0.0141, -1.1207,
#          -1.5065, -0.5211, -0.1223, -0.3771, -1.6405, -0.4135,  0.9795, -0.9815,
#           1.1310, -1.2054,  0.2074,  0.3348,  0.0601, -1.6650,  0.7387, -0.1587],
#         [ 1.1637, -1.3956, -0.8167, -0.6963,  0.3379,  0.8231,  0.0978, -0.2266,
#           0.3243, -0.9093, -1.2625, -0.7003,  0.0615,  0.8359,  0.9291, -0.1853,
#          -1.8688, -0.1602, -0.1307,  0.0359,  0.8640, -0.1056,  0.4484,  0.4781,
#          -0.0528, -0.1943,  0.0123, -0.2613,  0.9803,  0.1134, -0.6091, -0.3047],
#         [-0.8372,  1.1984, -0.3040,  0.4398,  0.8944,  1.1506, -1.6337,  0.5867,
#           0.7759, -0.1781, -0.5001, -0.6941,  0.1953, -0.2614, -2.3620, -0.4581,
#           0.0066, -0.1260,  0.3838,  1.7713,  0.4939,  0.4477,  1.1759, -0.2773,
#          -0.8439,  0.6795,  0.3088, -1.3569, -0.3223, -0.2440, -1.8864, -0.0715],
#         [ 1.6433, -1.4495,  0.1111, -0.4869,  0.5453,  0.8323, -0.4259, -0.3500,
#          -0.6107,  0.1296,  0.3073,  0.2287, -0.3437, -1.1729,  0.4661,  0.9376,
#          -0.4715,  1.0670, -0.4891, -0.6257,  0.7106, -0.7673,  0.2347, -0.3389,
#          -0.5389, -0.6152, -1.5303, -0.2078,  0.9710,  0.4468,  0.4987, -1.4814],
#         [ 0.0824,  0.6053, -0.1655,  0.3406, -0.6803, -1.7279,  0.1318, -0.3406,
#           0.0121,  1.5408, -1.8243, -1.2482,  0.1303, -0.6937,  0.8453, -0.6410,
#          -0.5131,  0.2371,  1.8217,  1.3965, -1.8074, -1.6920, -0.2417,  0.4346,
#          -0.6592, -0.7208, -0.2695, -0.0966, -0.9062, -0.5114, -0.4269, -0.5395],
#         [ 0.1917,  1.0195,  0.2685, -0.1917,  0.0389, -0.4268, -0.2732, -0.0428,
#          -0.2519,  0.0764, -0.3663,  1.6314, -1.7482, -0.4930,  0.5224,  0.1951,
#           0.8026,  1.8904, -0.7005, -0.2504,  0.2286, -0.7765, -0.4834,  1.5570,
#          -0.8850, -1.0472,  1.2167, -0.0862,  0.2633,  2.1902, -0.8020,  0.3407],
#         [-0.1059, -0.5035, -1.3680, -1.0858, -1.1859, -0.4658, -1.0809,  0.0318,
#          -1.9684, -0.5095,  0.4197,  0.1352, -1.9051,  0.6224, -0.2137,  0.0034,
#           1.1959,  0.1091,  0.7951, -1.8831,  0.3049, -1.8790,  0.1661, -0.6787,
#           1.2523, -0.7364, -0.0693, -0.2215,  0.6340,  0.2658,  2.0632,  0.0324],
#         [-1.3644, -0.2683,  1.0517,  0.6998,  0.4434,  0.5741,  1.8545,  0.5995,
#           1.1978,  0.8948, -0.0842, -0.9530, -0.5870, -0.2241, -0.1103, -0.1157,
#          -0.4179,  0.8462, -0.1077, -1.7632, -0.3258,  1.4560,  2.0391, -0.6113,
#          -0.7617, -1.5764,  0.6135,  1.3553,  0.5870, -2.5867, -0.9226,  0.9758],
#         [ 0.6166, -0.1183, -0.0380, -0.0371,  1.6221,  0.1908, -0.6989,  0.2924,
#           0.2068, -2.5948, -0.3516, -1.1644, -1.8035, -1.9298, -0.3197,  0.1466,
#          -0.3606,  0.8680,  0.6337, -1.2451, -0.2501, -1.0279, -0.4009,  0.3508,
#          -0.3176, -0.3023,  0.3549, -0.5574, -0.5501,  0.5856, -0.8431,  1.6596],
#         [-1.0615,  0.7467, -0.2357, -1.6972, -0.0691,  0.4728, -0.4416,  2.0986,
#          -0.7799, -1.6937, -0.8006,  0.6353, -0.8513,  1.0144,  0.9046,  0.8793,
#           0.4072,  0.2100, -1.6232, -1.6208,  0.8697,  0.2780,  0.8759,  0.4484,
#           1.0809,  0.0266, -0.3483, -1.4967, -0.3758,  0.8668, -1.6015,  0.4874],
#         [-1.1931, -0.2884,  0.6112,  1.5913,  0.6065,  0.3650, -1.0826,  0.8061,
#          -2.6491,  1.0327,  0.9823, -0.3521,  2.1042,  0.1473,  0.0931, -0.0005,
#           0.0041, -0.7983,  0.1764, -0.6376,  0.3999, -0.7201, -2.0012,  1.1704,
#           0.5419, -0.0057, -0.3000,  0.0887, -0.9006, -1.2255, -0.8590, -0.0915],
#         [ 1.4656,  0.4265,  1.6463,  1.0683, -0.5509, -0.6524,  0.5191, -1.7834,
#           2.8538, -0.0329,  0.8340, -0.0402, -0.1582,  0.1811,  0.5370,  0.0321,
#          -0.4698,  1.5708, -0.5984,  0.8162, -0.2128,  0.1234, -0.6581,  0.2994,
#           0.9541, -0.7034, -0.0605, -1.5105,  0.2496, -0.3083, -0.8945, -0.9164],
#         [ 0.4344,  0.7850, -0.9820,  0.3334, -1.6418,  1.1260, -0.7441,  0.9882,
#          -0.5583, -0.6229,  0.0732, -0.3319,  1.1219,  2.0298, -0.9959,  0.3119,
#           0.5976,  0.6445,  0.8218, -0.2735, -0.0039, -0.2386,  0.5484, -1.7629,
#           0.1171, -0.7982, -1.3972,  0.6503, -0.8689, -0.1705, -2.0115,  0.2074],
#         [-1.7828, -1.1699,  2.5045,  0.0294, -0.1066, -1.2281,  0.3349,  0.1281,
#          -1.4809,  0.2888, -0.4390,  1.1600,  0.3573,  0.0541,  1.4182,  0.2756,
#          -0.6367,  1.1699, -1.2282,  0.6555,  0.3969,  0.0624,  0.1165, -1.7368,
#           0.9463,  1.1016, -1.3492, -0.9043, -1.7249,  0.2901, -0.4836, -0.0004]]))])

# %%
import pandas as pd

# %%
test_data = pd.read_csv("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/test.csv")
test_data.head()
# Out:
#    Id        Word
# 0   1     PITCHED
# 1   2  DISSOLVERS
# 2   3     SCRAWNY
# 3   4   BONENFANT
# 4   5     EXCEEDS

# %%
x_test = list(test_data['Word'])
print(len(x_test))
print(type(x_test))
print(x_test[:10])
print(x_test[-10:])
# Out:
# 41597
# <class 'list'>
# ['PITCHED', 'DISSOLVERS', 'SCRAWNY', 'BONENFANT', 'EXCEEDS', 'BARTNICKI', 'BUTE', 'CAPITULATE', 'STEAM', 'INVESTCORP']
# ['HUPFER', 'LEATHERMAN', 'LUPATKIN', 'ELABORATELY', 'ARRUPE', 'INOCULATION', 'UNTO', 'SCOGIN', 'HESSION', 'TARNOWSKI']

# %%
print(x_test[0])
# Out:
# PITCHED

# %%
y_test = []

# %%
y_test = predict(encoder1, attn_decoder1, x_test)
# Out:
# Progress: 0 / 41597
# Progress: 1000 / 41597
# Progress: 2000 / 41597
# Progress: 3000 / 41597
# Progress: 4000 / 41597
# Progress: 5000 / 41597
# Progress: 6000 / 41597
# Progress: 7000 / 41597
# Progress: 8000 / 41597
# Progress: 9000 / 41597
# Progress: 10000 / 41597
# Progress: 11000 / 41597
# Progress: 12000 / 41597
# Progress: 13000 / 41597
# Progress: 14000 / 41597
# Progress: 15000 / 41597
# Progress: 16000 / 41597
# Progress: 17000 / 41597
# Progress: 18000 / 41597
# Progress: 19000 / 41597
# Progress: 20000 / 41597
# Progress: 21000 / 41597
# Progress: 22000 / 41597
# Progress: 23000 / 41597
# Progress: 24000 / 41597
# Progress: 25000 / 41597
# Progress: 26000 / 41597
# Progress: 27000 / 41597
# Progress: 28000 / 41597
# Progress: 29000 / 41597
# Progress: 30000 / 41597
# Progress: 31000 / 41597
# Progress: 32000 / 41597
# Progress: 33000 / 41597
# Progress: 34000 / 41597
# Progress: 35000 / 41597
# Progress: 36000 / 41597
# Progress: 37000 / 41597
# Progress: 38000 / 41597
# Progress: 39000 / 41597
# Progress: 40000 / 41597
# Progress: 41000 / 41597
# Finished!!!

# %%
for i in range(len(y_test)):
    y_test[i] = y_test[i][:-1]

# %%
print(y_test[:10])
# Out:
# ['P_IH_CH_T', 'D_AY_S_AH_L_V_ER_Z', 'S_K_R_AO_N_IY', 'B_AH_N_IH_N_F_AE_N_T', 'EH_K_S_K_K_K_K_S_IH_Z', 'B_AA_R_T_N_N_IH_K_IY', 'B_UW_T', 'K_AE_P_IH_T_AH_L_EY_T', 'S_T_EH_M', 'IH_N_AH_S_T_AH_S_T_AH_P_T']

# %%
submission = pd.read_csv("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/test.csv")
submission['Word'] = y_test

# %%
print(submission.head())
# Out:
#    Id                   Word
# 0   1              P_IH_CH_T
# 1   2     D_AY_S_AH_L_V_ER_Z
# 2   3          S_K_R_AO_N_IY
# 3   4   B_AH_N_IH_N_F_AE_N_T
# 4   5  EH_K_S_K_K_K_K_S_IH_Z

# %%
submission.to_csv("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/submission_baseline_tf=0.5_no_.csv")
