# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Downloading data

# %%
train_file = open("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/train.txt","r")
train = train_file.read()

# %%
train = train.split('\n')
train = train[:-1]
print("Examples in test dataset:", len(train))
x_train = [data_example.split(' ')[0] for data_example in train]
y_train = [data_example.split(' ')[1] for data_example in train]
# Out:
# Examples in test dataset: 83194

# %%
print("Examples in x_train = ", len(x_train))
print("Examples in y_train = ", len(y_train))
print(x_train[:5])
print
print(y_train[:5])
# Out:
# Examples in x_train =  83194
# Examples in y_train =  83194
# ['LEMIEUX', 'MINDING', 'STRIPED', 'KEN', 'CONFERENCE']
# ['L_AH_M_Y_UW', 'M_AY_N_D_IH_NG', 'S_T_R_AY_P_T', 'K_EH_N', 'K_AA_N_F_ER_AH_N_S']

# %%
print("Longest word in x_train -", max(x_train, key=len), "with len =", len(max(x_train, key=len)))
print("Longest word in y_train -", max(y_train, key=len), "with len =", len(max(y_train, key=len)))
# Out:
# Longest word in x_train - SUPERCALIFRAGILISTICEXPIALIDOCIOUS with len = 34
# Longest word in y_train - S_UW_P_ER_K_AE_L_AH_F_R_AE_JH_AH_L_IH_S_T_IH_K_EH_K_S_P_IY_AE_L_AH_D_OW_SH_AH_S with len = 79

# %% [markdown]
# ### First model architecture:
# Represent each char as one-hot, use seq2seq without attention

# %% [markdown]
# ### Second model architecture:
# Represent each char as embedding, use seq2seq without attention

# %% [markdown]
# ### Third model architecture:
# Represent each char as embedding, use seq2seq with attention

# %% [markdown]
# ### EXTRA Improvements:
# Train biderectional rnn

# %% [markdown]
# ### Preprocessing

# %%
SOS_token = 0
EOS_token = 1
MAX_LENGTH = 100

class Vocab:
    def __init__(self):
        self.char2idx = {'s': 0, 'e': 1}
        self.idx2char = {0: 's', 1: 'e'}
        self.n_words = 2
    
    def addWord(self, word):
        for char in word:
            self.addChar(char)
            
    def addChar(self, char):
        if char not in self.char2idx:
            self.char2idx[char] = self.n_words
            self.idx2char[self.n_words] = char
            self.n_words += 1
        
    def tokenize(self, sequence):
        return [self.char2idx[sym] for sym in sequence]
    
    def detokenize(self, sequence):
        return ''.join([self.idx2char[num] for num in sequence])

# %%
def readLang(x_train, y_train, reverse=False):
    input_lang = Vocab()
    output_lang = Vocab()
    
    pairs = []
    for word in x_train:
        input_lang.addWord(word)
    for word in y_train:
        output_lang.addWord(word)
        
    for i in range(len(x_train)):
         pairs.append([x_train[i], y_train[i]])
                       
    return input_lang, output_lang, pairs

# %%
input_lang, output_lang, pairs = readLang(x_train, y_train)

# %%
print(pairs[:10])
# Out:
# [['LEMIEUX', 'L_AH_M_Y_UW'], ['MINDING', 'M_AY_N_D_IH_NG'], ['STRIPED', 'S_T_R_AY_P_T'], ['KEN', 'K_EH_N'], ['CONFERENCE', 'K_AA_N_F_ER_AH_N_S'], ['IMMOLATE', 'IH_M_AH_L_EY_T'], ['TRANSGRESS', 'T_R_AE_N_Z_G_R_EH_S'], ['RABBLE', 'R_AE_B_AH_L'], ['AIRSHARE', 'EH_R_SH_EH_R'], ['INTOLERANCE', 'IH_N_T_AA_L_ER_AH_N_S']]

# %%
print(random.choice(pairs))
# Out:
# ['PATRIDGE', 'P_AE_T_R_IH_JH']

# %%
for key,value in input_lang.char2idx.items():
    print(key, " - ", value)
# Out:
# s  -  0
# e  -  1
# L  -  2
# E  -  3
# M  -  4
# I  -  5
# U  -  6
# X  -  7
# N  -  8
# D  -  9
# G  -  10
# S  -  11
# T  -  12
# R  -  13
# P  -  14
# K  -  15
# C  -  16
# O  -  17
# F  -  18
# A  -  19
# B  -  20
# H  -  21
# V  -  22
# Y  -  23
# W  -  24
# J  -  25
# '  -  26
# Q  -  27
# Z  -  28
# -  -  29

# %%
for key,value in output_lang.char2idx.items():
    print(key, " - ", value)
# Out:
# s  -  0
# e  -  1
# L  -  2
# _  -  3
# A  -  4
# H  -  5
# M  -  6
# Y  -  7
# U  -  8
# W  -  9
# N  -  10
# D  -  11
# I  -  12
# G  -  13
# S  -  14
# T  -  15
# R  -  16
# P  -  17
# K  -  18
# E  -  19
# F  -  20
# Z  -  21
# B  -  22
# V  -  23
# O  -  24
# J  -  25
# C  -  26

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
    class AttnDecoderRNN(nn.Module):
        def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
            super(AttnDecoderRNN, self).__init__()
            self.hidden_size = hidden_size
            self.output_size = output_size
            self.dropout_p = dropout_p
            self.max_length = max_length

            self.embedding = nn.Embedding(self.output_size, self.hidden_size)
            self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
            self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
            self.dropout = nn.Dropout(self.dropout_p)
            self.gru = nn.GRU(self.hidden_size, self.hidden_size)
            self.out = nn.Linear(self.hidden_size, self.output_size)

        def forward(self, input, hidden, encoder_outputs):
            embedded = self.embedding(input).view(1, 1, -1)
            embedded = self.dropout(embedded)

            attn_weights = F.softmax(
                self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
            attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                     encoder_outputs.unsqueeze(0))

            output = torch.cat((embedded[0], attn_applied[0]), 1)
            output = self.attn_combine(output).unsqueeze(0)

            output = F.relu(output)
            output, hidden = self.gru(output, hidden)

            output = F.log_softmax(self.out(output[0]), dim=1)
            return output, hidden, attn_weights

        def initHidden(self):
            return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Training

# %%
def indexesFromWord(vocab, word):
    return [vocab.char2idx[char] for char in word]

def tensorFromWord(vocab, word):
    indexes = indexesFromWord(vocab, word)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromWord(input_lang, pair[0])
    target_tensor = tensorFromWord(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromWord(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                #decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.idx2char[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]
    
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ''.join(output_words)
        print('<', output_sentence)
        print('')

# %%
def predict(encoder, decoder, x):
    y = []
    for i in range(len(x)):
        if i % 1000 == 0:
            print("Progress:", i, "/", len(x))
        output_words, _ = evaluate(encoder, decoder, x[i])
        output_sentence = ''.join(output_words)
        output_sentence = output_sentence
        y.append(output_sentence)
    print("Finished!!! ")
    return y

# %%
hidden_size = 512
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

# %%
trainIters(encoder1, attn_decoder1, 100000, print_every=1000)
# Out:
# 2m 6s (- 208m 43s) (1000 1%) 2.0674
# 4m 5s (- 200m 15s) (2000 2%) 1.9046
# 6m 5s (- 196m 48s) (3000 3%) 1.8758
# 8m 5s (- 194m 11s) (4000 4%) 1.9015
# 10m 4s (- 191m 34s) (5000 5%) 1.6106
# 12m 3s (- 188m 47s) (6000 6%) 1.3537
# 14m 1s (- 186m 16s) (7000 7%) 1.2378
# 16m 0s (- 184m 3s) (8000 8%) 1.1200
# 17m 56s (- 181m 28s) (9000 9%) 1.0387
# 19m 56s (- 179m 25s) (10000 10%) 1.0385
# 21m 57s (- 177m 37s) (11000 11%) 1.0017
# 23m 57s (- 175m 40s) (12000 12%) 0.9784
# 25m 57s (- 173m 43s) (13000 13%) 0.9217
# 27m 57s (- 171m 44s) (14000 14%) 0.9129
# 29m 56s (- 169m 39s) (15000 15%) 0.8540
# 31m 55s (- 167m 34s) (16000 16%) 0.8322
# 33m 55s (- 165m 38s) (17000 17%) 0.8119
# 35m 54s (- 163m 34s) (18000 18%) 0.8124
# 37m 54s (- 161m 35s) (19000 19%) 0.7855
# 39m 54s (- 159m 36s) (20000 20%) 0.8090
# 41m 54s (- 157m 40s) (21000 21%) 0.7989
# 43m 53s (- 155m 36s) (22000 22%) 0.7391
# 45m 52s (- 153m 36s) (23000 23%) 0.7250
# 47m 52s (- 151m 36s) (24000 24%) 0.7563
# 49m 52s (- 149m 38s) (25000 25%) 0.7483
# 51m 50s (- 147m 34s) (26000 26%) 0.7349
# 53m 49s (- 145m 32s) (27000 27%) 0.7540
# 55m 48s (- 143m 31s) (28000 28%) 0.7114
# 57m 48s (- 141m 32s) (29000 28%) 0.7119
# 59m 46s (- 139m 28s) (30000 30%) 0.6552
# 61m 46s (- 137m 29s) (31000 31%) 0.6539
# 63m 46s (- 135m 31s) (32000 32%) 0.6261
# 65m 47s (- 133m 33s) (33000 33%) 0.6934
# 67m 48s (- 131m 37s) (34000 34%) 0.6286
# 69m 47s (- 129m 35s) (35000 35%) 0.5934
# 71m 41s (- 127m 27s) (36000 36%) 0.6200
# 73m 30s (- 125m 9s) (37000 37%) 0.6079
# 75m 16s (- 122m 49s) (38000 38%) 0.5961
# 77m 4s (- 120m 33s) (39000 39%) 0.6604
# 78m 53s (- 118m 20s) (40000 40%) 0.6575
# 80m 41s (- 116m 7s) (41000 41%) 0.6093
# 82m 28s (- 113m 53s) (42000 42%) 0.6068
# 84m 16s (- 111m 43s) (43000 43%) 0.6174
# 86m 4s (- 109m 33s) (44000 44%) 0.6005
# 87m 53s (- 107m 25s) (45000 45%) 0.5665
# 89m 40s (- 105m 16s) (46000 46%) 0.5943
# 91m 28s (- 103m 9s) (47000 47%) 0.5930
# 93m 17s (- 101m 3s) (48000 48%) 0.5694
# 95m 7s (- 99m 0s) (49000 49%) 0.5449
# 96m 55s (- 96m 55s) (50000 50%) 0.5646
# 98m 44s (- 94m 51s) (51000 51%) 0.5598
# 100m 32s (- 92m 48s) (52000 52%) 0.5877
# 102m 21s (- 90m 46s) (53000 53%) 0.5595
# 104m 9s (- 88m 43s) (54000 54%) 0.5348
# 105m 57s (- 86m 41s) (55000 55%) 0.5637
# 107m 45s (- 84m 39s) (56000 56%) 0.5499
# 109m 34s (- 82m 39s) (57000 56%) 0.5781
# 111m 22s (- 80m 39s) (58000 57%) 0.5526
# 113m 13s (- 78m 40s) (59000 59%) 0.5547
# 114m 59s (- 76m 39s) (60000 60%) 0.5326
# 116m 47s (- 74m 40s) (61000 61%) 0.5654
# 118m 35s (- 72m 41s) (62000 62%) 0.5610
# 120m 25s (- 70m 43s) (63000 63%) 0.5670
# 122m 14s (- 68m 45s) (64000 64%) 0.5220
# 124m 2s (- 66m 47s) (65000 65%) 0.5269
# 125m 48s (- 64m 48s) (66000 66%) 0.5217
# 127m 37s (- 62m 51s) (67000 67%) 0.5595
# 129m 26s (- 60m 54s) (68000 68%) 0.5321
# 131m 15s (- 58m 58s) (69000 69%) 0.5123
# 133m 4s (- 57m 1s) (70000 70%) 0.5605
# 134m 52s (- 55m 5s) (71000 71%) 0.5585
# 136m 40s (- 53m 9s) (72000 72%) 0.5203
# 138m 29s (- 51m 13s) (73000 73%) 0.4896
# 140m 17s (- 49m 17s) (74000 74%) 0.5271
# 142m 5s (- 47m 21s) (75000 75%) 0.5256
# 143m 54s (- 45m 26s) (76000 76%) 0.5266
# 145m 43s (- 43m 31s) (77000 77%) 0.5304
# 147m 32s (- 41m 36s) (78000 78%) 0.5181
# 149m 20s (- 39m 41s) (79000 79%) 0.5071
# 151m 7s (- 37m 46s) (80000 80%) 0.5123
# 152m 56s (- 35m 52s) (81000 81%) 0.5132
# 154m 44s (- 33m 58s) (82000 82%) 0.5162
# 156m 32s (- 32m 3s) (83000 83%) 0.5225
# 158m 21s (- 30m 9s) (84000 84%) 0.5055
# 160m 9s (- 28m 15s) (85000 85%) 0.5048
# 161m 59s (- 26m 22s) (86000 86%) 0.5345
# 163m 47s (- 24m 28s) (87000 87%) 0.5090
# 165m 36s (- 22m 35s) (88000 88%) 0.4915
# 167m 26s (- 20m 41s) (89000 89%) 0.4943
# 169m 15s (- 18m 48s) (90000 90%) 0.4813
# 171m 1s (- 16m 54s) (91000 91%) 0.4668
# 172m 50s (- 15m 1s) (92000 92%) 0.4973
# 174m 38s (- 13m 8s) (93000 93%) 0.4940
# 176m 26s (- 11m 15s) (94000 94%) 0.5173
# 178m 18s (- 9m 23s) (95000 95%) 0.4641
# 180m 7s (- 7m 30s) (96000 96%) 0.4650
# 181m 55s (- 5m 37s) (97000 97%) 0.4942
# 183m 44s (- 3m 44s) (98000 98%) 0.5100
# 185m 32s (- 1m 52s) (99000 99%) 0.4663
# 187m 19s (- 0m 0s) (100000 100%) 0.4903

# %%
path = "/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/Models/"
torch.save(encoder1.state_dict(), path + "encoder_baseline_hd=512")
torch.save(attn_decoder1.state_dict(), path + "decoder_baseline_hd=512")

# %%
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
encoder1.load_state_dict(torch.load(path + "encoder_baseline"))
encoder1.eval()

attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
attn_decoder1.load_state_dict(torch.load(path + "decoder_baseline"))
attn_decoder1.eval()
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(27, 256)
#   (attn): Linear(in_features=512, out_features=100, bias=True)
#   (attn_combine): Linear(in_features=512, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1)
#   (gru): GRU(256, 256)
#   (out): Linear(in_features=256, out_features=27, bias=True)
# )

# %% [markdown]
# #### Postprocessing:
# trim extra '_' symbols

# %%
predicted = predict(encoder1, attn_decoder1, x_train[:5000])
# Out:
# Progress: 0 / 5000
# Progress: 1000 / 5000
# Progress: 2000 / 5000
# Progress: 3000 / 5000
# Progress: 4000 / 5000
# Finished!!!

# %%
count = 0
for i in range(len(predicted)):
    if y_train[i] == predicted[i]:
        print("+++++++++")
    else:
        print("---------")
        print("Phonemes in original word:", y_train[i].count('_') + 1)
        print("Phonemse in predicted word:", predicted[i].count('_') + 1)
    print("Word:", x_train[i])
    print("Original:", y_train[i])
    print("Predict:", predicted[i])
    print()
    if y_train[i] == predicted[i]:
        count += 1
print("Accuracy =", count/len(predicted))
# Out:
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: LEMIEUX
# Original: L_AH_M_Y_UW
# Predict: L_IH_M_IY_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MINDING
# Original: M_AY_N_D_IH_NG
# Predict: M_IH_N_D_IH_NG
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: STRIPED
# Original: S_T_R_AY_P_T
# Predict: S_T_R_IY_P_D
#
# +++++++++
# Word: KEN
# Original: K_EH_N
# Predict: K_EH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: CONFERENCE
# Original: K_AA_N_F_ER_AH_N_S
# Predict: K_AH_N_F_ER_AH_N_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: IMMOLATE
# Original: IH_M_AH_L_EY_T
# Predict: IH_M_O__L_EY_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: TRANSGRESS
# Original: T_R_AE_N_Z_G_R_EH_S
# Predict: T_R_AE_NG_Z_R_EH_S
#
# +++++++++
# Word: RABBLE
# Original: R_AE_B_AH_L
# Predict: R_AE_B_AH_L
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: AIRSHARE
# Original: EH_R_SH_EH_R
# Predict: ER_SH_EH_R
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 12
# Word: INTOLERANCE
# Original: IH_N_T_AA_L_ER_AH_N_S
# Predict: IH_N_T_AO_L_R_EH_N_S__H_N
#
# +++++++++
# Word: ILVA
# Original: IH_L_V_AH
# Predict: IH_L_V_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: RYGEL
# Original: R_IH_G_EH_L
# Predict: R_IY_G_AH_L
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MARLETTE
# Original: M_AA_R_L_EH_T
# Predict: M_AA_R_L_AH_T
#
# +++++++++
# Word: DILDO
# Original: D_IH_L_D_OW
# Predict: D_IH_L_D_OW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: ORELIA
# Original: AO_R_EH_L_IY_AH
# Predict: AO_R_IY_L_IY_AH
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MCNISH
# Original: M_AH_K_N_IH_SH
# Predict: M_AH_N_S_IH_
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: FURBISHED
# Original: F_ER_B_IH_SH_T
# Predict: F_ER_B_IH_SH_T_IH_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 4
# Word: COMFED
# Original: K_AA_M_F_EH_D
# Predict: K_AH_M_F
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 10
# Word: WALKENHORST
# Original: W_AO_K_AH_N_HH_AO_R_S_T
# Predict: W_AO_L_S_IH_N_AA_AR_T_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: MILLIRONS
# Original: M_IH_L_ER_OW_N_Z
# Predict: M_IH_L_ER_A__N_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 3
# Word: JERE
# Original: JH_EH_R_IY
# Predict: JH_EH_R
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: LIVAN'S
# Original: L_IY_V_AA_N_Z
# Predict: L_IY_V_AH_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: PREVIEW
# Original: P_R_IY_V_Y_UW
# Predict: P_R_EY_V_IY_W_
#
# +++++++++
# Word: GRAYING
# Original: G_R_EY_IH_NG
# Predict: G_R_EY_IH_NG
#
# ---------
# Phonemes in original word: 2
# Phonemse in predicted word: 4
# Word: KU
# Original: K_UW
# Predict: K_UH_W_
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: FREEHOLD
# Original: F_R_IY_HH_OW_L_D
# Predict: F_R_IY_HH_AW_L_D
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: CONCA
# Original: K_AA_NG_K_AH
# Predict: K_AA_N_K_AH
#
# +++++++++
# Word: TECK'S
# Original: T_EH_K_S
# Predict: T_EH_K_S
#
# +++++++++
# Word: QUINTER
# Original: K_W_IH_N_T_ER
# Predict: K_W_IH_N_T_ER
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 17
# Word: CIRCUMSTANTIAL
# Original: S_ER_K_AH_M_S_T_AE_N_SH_AH_L
# Predict: K_ER_K_M_AH_K_S__A__N_AH____L_A
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: RYDELL
# Original: R_IH_D_AH_L
# Predict: R_AY_D_AH_L
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 6
# Word: ROTOTILLER
# Original: R_OW_T_AH_T_IH_L_ER
# Predict: R_OW_T_AH_L_ER
#
# +++++++++
# Word: HAVINGTON'S
# Original: HH_AE_V_IH_NG_T_AH_N_Z
# Predict: HH_AE_V_IH_NG_T_AH_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: DECALS
# Original: D_IY_K_AE_L_Z
# Predict: D_IY_K_AH_L_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: DIBATTISTA
# Original: D_IH_B_AA_T_IY_S_T_AA
# Predict: D_IY_B_AA_S_IY_AH_AAAA
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: RAVI'S
# Original: R_AA_V_IY_S
# Predict: R_AE_V_IY_Z
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 10
# Word: INTERCEPTING
# Original: IH_N_T_ER_S_EH_P_T_IH_NG
# Predict: IH_N_T_ER_P_EH_T_T_IH_NGN
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: FROMMELT
# Original: F_R_AA_M_IH_L_T
# Predict: F_R_AA_M_AH_L_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: ACCOMPANIED
# Original: AH_K_AH_M_P_AH_N_IY_D
# Predict: AH_K_M_AH_P_AY_N_D
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 12
# Word: WHOLESALING
# Original: HH_OW_L_S_EY_L_IH_NG
# Predict: W__Y_L_S__H__G_NG_AH_NG
#
# +++++++++
# Word: APHIDS
# Original: AE_F_IH_D_Z
# Predict: AE_F_IH_D_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: LULLING
# Original: L_AH_L_IH_NG
# Predict: L_AH_N_IH_NG
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: HAIDA
# Original: HH_AY_D_AH
# Predict: HH_EY_D_AH
#
# +++++++++
# Word: REDDITT
# Original: R_EH_D_IH_T
# Predict: R_EH_D_IH_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: WRONSKI
# Original: R_AA_N_S_K_IY
# Predict: W_AA_R_N_S_K_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: AVERYL
# Original: AE_V_ER_IH_L
# Predict: AY_V_ER_IH_L
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: PROPELLED
# Original: P_R_AH_P_EH_L_D
# Predict: P_R_AA_P_IH_L_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: MAGRUDER
# Original: M_AH_G_R_UW_D_ER
# Predict: M_AE_G_W_ER_D_ER
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: EMBEZZLES
# Original: IH_M_B_EH_Z_AH_L_Z
# Predict: EH_M_B_AH_L_AH_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: MCNINCH
# Original: M_AH_K_N_IH_N_CH
# Predict: M_AH_K_N_IH_K
#
# +++++++++
# Word: DANDURAND
# Original: D_AE_N_D_ER_AH_N_D
# Predict: D_AE_N_D_ER_AH_N_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: REVIEWS
# Original: R_IY_V_Y_UW_Z
# Predict: R_IY_V_IY_W__Z
#
# +++++++++
# Word: B'RITH
# Original: B_R_IH_TH
# Predict: B_R_IH_TH
#
# ---------
# Phonemes in original word: 16
# Phonemse in predicted word: 23
# Word: UNCHARACTERISTICALLY
# Original: AH_N_K_EH_R_IH_K_T_ER_IH_S_T_IH_K_L_IY
# Predict: AH_N__E_EH__________________Y
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 9
# Word: GANCARZ
# Original: G_AA_N_K_AA_R_Z
# Predict: G_AE_N_K_AA_R__H_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: RUTSTEIN
# Original: R_AH_T_S_T_AY_N
# Predict: R_AH_S_T_IY_N
#
# +++++++++
# Word: FRIDRICH
# Original: F_R_IH_D_R_IH_K
# Predict: F_R_IH_D_R_IH_K
#
# +++++++++
# Word: KOZIK
# Original: K_OW_Z_IH_K
# Predict: K_OW_Z_IH_K
#
# +++++++++
# Word: EBBING
# Original: EH_B_IH_NG
# Predict: EH_B_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: BRIDGHAM
# Original: B_R_IH_JH_HH_AH_M
# Predict: B_R_IH_JH_AH_M
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: ELLENBERGER
# Original: EH_L_AH_N_B_ER_G_ER
# Predict: EH_L_IH_N_B_ER_G_ER
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: DISORDERS
# Original: D_IH_S_AO_R_D_ER_Z
# Predict: D_IH_S_AO_D_ER_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: ATHLETICALLY
# Original: AE_TH_L_EH_T_IH_K_L_IY
# Predict: AE_TH_IH_T_L_IY_K_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: KRAKOW
# Original: K_R_AA_K_AW
# Predict: K_R_AE_K_OW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SOLVIG
# Original: S_OW_L_V_IH_G
# Predict: S_AW_L_V_IH_G
#
# +++++++++
# Word: SLURRED
# Original: S_L_ER_D
# Predict: S_L_ER_D
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: CONCOURSES
# Original: K_AA_N_K_AO_R_S_IH_Z
# Predict: K_AH_N_K_AO_R__H_Z
#
# +++++++++
# Word: BRUNNER
# Original: B_R_AH_N_ER
# Predict: B_R_AH_N_ER
#
# +++++++++
# Word: SKINNER
# Original: S_K_IH_N_ER
# Predict: S_K_IH_N_ER
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: VIOLIST'S
# Original: V_IY_OW_L_AH_S_T_S
# Predict: V_AY_AH_L_IH_S_T_S
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 10
# Word: ENCEPHALITIS
# Original: EH_N_S_EH_F_AH_L_AY_T_AH_S
# Predict: IH_N_S_EE_F_L_EE_SH_AY_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MASEK
# Original: M_AA_S_EH_K
# Predict: M_AH_S_IH_K
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: REINSTATED
# Original: R_IY_IH_N_S_T_EY_T_IH_D
# Predict: R_IY_IH_N_S_T_IH_T_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CHIAPAS'
# Original: CH_IY_AA_P_AH_Z
# Predict: CH_IY_AE_P_AH_Z
#
# +++++++++
# Word: AGERS
# Original: EY_JH_ER_Z
# Predict: EY_JH_ER_Z
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: SCHIELE
# Original: SH_IY_L
# Predict: SH_AY_AH_L
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: APOLOGIST
# Original: AH_P_AA_L_AH_JH_IH_S_T
# Predict: AE_P_AH_L_AH_JH_IH_S_T
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: ESME
# Original: EH_Z_M
# Predict: EH_S_M
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: BREASTING
# Original: B_R_EH_S_T_IH_NG
# Predict: B_R_EY_S_T_IH_NG
#
# +++++++++
# Word: HERMON
# Original: HH_ER_M_AH_N
# Predict: HH_ER_M_AH_N
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 10
# Word: INTERROGATIONS
# Original: IH_N_T_EH_R_AH_G_EY_SH_AH_N_Z
# Predict: IH_N_T_ER_G_EY_SH_AH_N_Z
#
# +++++++++
# Word: ZAN
# Original: Z_AE_N
# Predict: Z_AE_N
#
# +++++++++
# Word: FLAPPERS
# Original: F_L_AE_P_ER_Z
# Predict: F_L_AE_P_ER_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: GYMNASIUM
# Original: JH_IH_M_N_EY_Z_IY_AH_M
# Predict: JH_IH_N_AH_S__AH_M
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: VIEWERS
# Original: V_Y_UW_ER_Z
# Predict: V_IY_W_ER_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: DIVERSIFIED
# Original: D_AY_V_ER_S_AH_F_AY_D
# Predict: D_AY_V_ER_S_AY_F_AY_D
#
# +++++++++
# Word: ECKLAND
# Original: EH_K_L_AH_N_D
# Predict: EH_K_L_AH_N_D
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: KUOMINTANG
# Original: K_W_OW_M_IH_N_T_AE_NG
# Predict: K_Y_UM_M_AH_N_TT_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 7
# Word: CODRESCU
# Original: K_AH_D_R_EH_S_K_Y_UW
# Predict: K_AH_D_R_EH_S_UW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: ADONIS
# Original: AH_D_AA_N_AH_S
# Predict: AH_D_AH_N_IH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SEAMUS
# Original: SH_EY_M_AH_S
# Predict: S_IY_M_AH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 4
# Word: MARUYU
# Original: M_EH_R_UW_Y_UW
# Predict: M_EE_R_UW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: PRUSSAK
# Original: P_R_AH_S_AH_K
# Predict: P_R_AH_S_AE_K
#
# +++++++++
# Word: GUSSIED
# Original: G_AH_S_IY_D
# Predict: G_AH_S_IY_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 5
# Word: GIAMPAPA
# Original: JH_AA_M_P_AA_P_AA
# Predict: JH_AY_M_P_AA
#
# +++++++++
# Word: MARCOM
# Original: M_AA_R_K_AH_M
# Predict: M_AA_R_K_AH_M
#
# +++++++++
# Word: TERM'S
# Original: T_ER_M_Z
# Predict: T_ER_M_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MAHANY
# Original: M_AE_HH_AH_N_IY
# Predict: M_AH_HH_AE_N_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: DISSOLVE
# Original: D_IH_Z_AA_L_V
# Predict: D_IH_S_AH_L_V
#
# +++++++++
# Word: MAP
# Original: M_AE_P
# Predict: M_AE_P
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: DISSENT
# Original: D_IH_S_EH_N_T
# Predict: D_IH_S_AH_N_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: CAPON
# Original: K_EY_P_AA_N
# Predict: K_AE_P_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: PERCENTS
# Original: P_ER_S_EH_N_T_S
# Predict: P_ER_S_AH_N_T_S
#
# +++++++++
# Word: NOKIA
# Original: N_OW_K_IY_AH
# Predict: N_OW_K_IY_AH
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 13
# Word: CROSS-POLLINATE
# Original: K_R_AO_S_P_AA_L_AH_N_EY_T
# Predict: K_R_AH_S_P_AH_L_EH_L_EY_N_EH_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: DESAUTEL
# Original: D_EH_S_OW_T_AH_L
# Predict: D_IH_S_AH_T_AH_L_A
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: WANNEMACHER
# Original: W_AA_N_AH_M_AA_K_ER
# Predict: W_AE_N_IY_M_ER_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: SHARPEST
# Original: SH_AA_R_P_AH_S_T
# Predict: SH_AA_R_P_EH_S_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: LOCKLAIR
# Original: L_AA_K_L_ER
# Predict: L_AA_K_L_EY_ER
#
# +++++++++
# Word: DISK
# Original: D_IH_S_K
# Predict: D_IH_S_K
#
# +++++++++
# Word: PRAISING
# Original: P_R_EY_Z_IH_NG
# Predict: P_R_EY_Z_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: MANCEBO
# Original: M_AA_N_CH_EH_B_OW
# Predict: M_AE_N_S_B_AH_OW
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: LOCA
# Original: L_OW_K_AH
# Predict: L_OA_K_AH
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 11
# Word: TUBERCULOSIS
# Original: T_AH_B_ER_K_Y_AH_L_OW_S_IH_S
# Predict: T_UW_B_ER_CH_AH_K_AH_L_AY_S
#
# +++++++++
# Word: DITMARS
# Original: D_IH_T_M_ER_Z
# Predict: D_IH_T_M_ER_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: DIVISIBLE
# Original: D_IH_V_IH_Z_AH_B_AH_L
# Predict: D_AY_V_AH_S_AH_B_AH_L
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 10
# Word: DELEGATIONS
# Original: D_EH_L_AH_G_EY_SH_AH_N_Z
# Predict: D_IH_L_AH_G_EY_SH_AH_N_Z
#
# +++++++++
# Word: PLAINO
# Original: P_L_EY_N_OW
# Predict: P_L_EY_N_OW
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: AVERITT
# Original: AE_V_ER_IH_T
# Predict: AE_V_EH_R_IH_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: ALONZO
# Original: AH_L_AA_N_Z_OW
# Predict: AA_L_AA_N_OW_Z_OW
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: MCKEEHAN
# Original: M_AH_K_IY_HH_AH_N
# Predict: M_AH_K_EY_SH_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: ENFORCER
# Original: EH_N_F_AO_R_S_ER
# Predict: IH_N_F_AO_R_K_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: APEC'S
# Original: EY_P_EH_K_S
# Predict: AE_P_EH_K_S
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 11
# Word: LIBERTARIAN
# Original: L_IH_B_ER_T_EH_R_IY_AH_N
# Predict: L_IY_B_ER_T_EH____N_
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: HOW'RE
# Original: HH_AW_ER
# Predict: HH_AW_E
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: BONNET
# Original: B_AA_N_AH_T
# Predict: B_AA_N_IH_T
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: REALIGNING
# Original: R_IY_AH_L_AY_N_IH_NG
# Predict: R_IY_L_AY_NG_G_IH_NG
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: MISSPOKEN
# Original: M_IH_S_S_P_OW_K_AH_N
# Predict: M_IH_S_P_OH_K_AH_N
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 3
# Word: KUZE
# Original: K_Y_UW_Z
# Predict: K_AW_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: KARCHER
# Original: K_AA_R_CH_ER
# Predict: K_AA_R_K_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 5
# Word: APPENDED
# Original: AH_P_EH_N_D_IH_D
# Predict: AH_P_EH_N_D
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: BACKDROPS
# Original: B_AE_K_D_R_AA_P_S
# Predict: B_AE_K_D_AO_R_P_S
#
# +++++++++
# Word: EDELSON
# Original: EH_D_IH_L_S_AH_N
# Predict: EH_D_IH_L_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: NEWMONT'S
# Original: N_UW_M_AA_N_T_S
# Predict: N_UW_M_AH_N_T_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: MELCHOR
# Original: M_EH_L_CH_ER
# Predict: M_EH_CH_ER
#
# +++++++++
# Word: SCHWARTZ
# Original: SH_W_AO_R_T_S
# Predict: SH_W_AO_R_T_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: WRESTLERS
# Original: R_EH_S_L_ER_Z
# Predict: R_EH_S_T_L_ER_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: HOLLOWAY
# Original: HH_AA_L_OW_W_EY
# Predict: HH_AH_L_W_EY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: SOFTEST
# Original: S_AO_F_T_AH_S_T
# Predict: S_AO_F_S_EH_S_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HEATLEY
# Original: HH_IY_T_L_IY
# Predict: HH_EY_T_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: FIATO
# Original: F_IY_AE_T_OW
# Predict: F_IY_AH_T_OW
#
# +++++++++
# Word: GLOD
# Original: G_L_AA_D
# Predict: G_L_AA_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: PROKOP
# Original: P_R_OW_K_AH_P
# Predict: P_R_AA_K_AA_P
#
# +++++++++
# Word: SHOCKS
# Original: SH_AA_K_S
# Predict: SH_AA_K_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: KEYNESIAN
# Original: K_EY_N_Z_IY_AH_N
# Predict: K_EY_N_IH_S_IY_AH_N
#
# +++++++++
# Word: MARSHA
# Original: M_AA_R_SH_AH
# Predict: M_AA_R_SH_AH
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: FARSIGHTED
# Original: F_AA_R_S_AY_T_AH_D
# Predict: F_AA_R_S_IY_T_AH_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: NARROWEST
# Original: N_EH_R_OW_AH_S_T
# Predict: N_AH_R_AW_W_AH_S_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SKURKA
# Original: S_K_ER_K_AA
# Predict: S_K_ER_K_AH
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: ALTOMARE
# Original: AA_L_T_OW_M_AA_R_IY
# Predict: AO_L_T_AH_M_EY_E
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: STANKEVICH
# Original: S_T_AE_NG_K_AH_V_IH_CH
# Predict: S_T_AE_NG_K_IH_V_IH_CH
#
# +++++++++
# Word: BLECH'S
# Original: B_L_EH_K_S
# Predict: B_L_EH_K_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: DOUGANS
# Original: D_AW_G_AH_N
# Predict: D_AW_G_AH_N_Z
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 10
# Word: HALLUCINATION
# Original: HH_AH_L_UW_S_AH_N_EY_SH_AH_N
# Predict: HH_AE_L_Y_UW_SH_AY_SH_AH_N
#
# +++++++++
# Word: SCANNING
# Original: S_K_AE_N_IH_NG
# Predict: S_K_AE_N_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: TEDESCO
# Original: T_EH_D_EH_S_K_OW
# Predict: T_EH_D_AH_S_K_OW
#
# +++++++++
# Word: GOLTZ
# Original: G_OW_L_T_S
# Predict: G_OW_L_T_S
#
# +++++++++
# Word: BASCO
# Original: B_AA_S_K_OW
# Predict: B_AA_S_K_OW
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: FATALISTS
# Original: F_EY_T_AH_L_IH_S_T_S
# Predict: F_AH_T_AH_L_IH_T_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 7
# Word: ULTIMATUM
# Original: AH_L_T_AH_M_EY_T_AH_M
# Predict: AH_L_T_IH_M_UW_M
#
# +++++++++
# Word: BURRER
# Original: B_ER_ER
# Predict: B_ER_ER
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 13
# Word: AMBIDEXTROUS
# Original: AE_M_B_IH_D_EH_K_S_T_R_AH_S
# Predict: AE_M_B_IH_K_D_R_IY_AH_T__H_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: OPEL'S
# Original: OW_P_AH_L_Z
# Predict: AA_P_AH_L_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: HEDGPETH
# Original: HH_EH_JH_P_IH_TH
# Predict: HH_EH_JH_P_EH_T
#
# +++++++++
# Word: SPINDLE
# Original: S_P_IH_N_D_AH_L
# Predict: S_P_IH_N_D_AH_L
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 10
# Word: TRIGLYCERIDES
# Original: T_R_AY_G_L_IH_S_ER_AY_D_Z
# Predict: T_R_IY_G_L_IH_K_R_IY_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: FUSON
# Original: F_UW_S_AH_N
# Predict: F_AH_S_AH_N
#
# +++++++++
# Word: SECTION'S
# Original: S_EH_K_SH_AH_N_Z
# Predict: S_EH_K_SH_AH_N_Z
#
# +++++++++
# Word: HAFEY
# Original: HH_EY_F_IY
# Predict: HH_EY_F_IY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 10
# Word: RESIDENCIES
# Original: R_EH_Z_IH_D_EH_N_S_IY_Z
# Predict: R_IH_S_IH_D_AH_N_S_IY_Z
#
# +++++++++
# Word: BEHM
# Original: B_EH_M
# Predict: B_EH_M
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: KROTKOV
# Original: K_R_AO_T_K_AO_V
# Predict: K_R_AA_T_K_AA_V
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: CELOSIA
# Original: CH_EH_L_OW_S_IY_AH
# Predict: CH_EH_L_OY_S__AH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: PAPERWORK
# Original: P_EY_P_ER_W_ER_K
# Predict: P_EH_P_EH_R_AO_R_K
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: STRESSED
# Original: S_T_R_EH_S_T
# Predict: S_T_R_EH_S_D
#
# +++++++++
# Word: PRIDDY
# Original: P_R_IH_D_IY
# Predict: P_R_IH_D_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: COTY
# Original: K_OW_T_IY
# Predict: K_OA_T_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: RECRUIT'S
# Original: R_IY_K_R_UW_T_S
# Predict: R_EH_K_W_AH_T_S
#
# +++++++++
# Word: HANNAM
# Original: HH_AE_N_AH_M
# Predict: HH_AE_N_AH_M
#
# +++++++++
# Word: BELLMON
# Original: B_EH_L_M_AH_N
# Predict: B_EH_L_M_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: ENGLAND
# Original: IH_NG_G_L_AH_N_D
# Predict: IH_NG_G_L_AE_N_D
#
# +++++++++
# Word: ENTICING
# Original: EH_N_T_AY_S_IH_NG
# Predict: EH_N_T_AY_S_IH_NG
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: DOBBIN
# Original: D_AA_B_IH_N
# Predict: D_AA_B_B_IH_N
#
# ---------
# Phonemes in original word: 2
# Phonemse in predicted word: 3
# Word: VAUGH
# Original: V_AO
# Predict: V_AO_F
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: KLEJNA
# Original: K_L_EY_N_ER
# Predict: K_L_IH_N_JH_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: PUNTO
# Original: P_UW_N_T_OW
# Predict: P_AH_N_T_OW
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: MANDATED
# Original: M_AE_N_D_EY_T_IH_D
# Predict: M_AE_N_D_AY_T_IH_D
#
# +++++++++
# Word: FOGELSON
# Original: F_OW_G_AH_L_S_AH_N
# Predict: F_OW_G_AH_L_S_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: HARTSOCK
# Original: HH_AA_R_T_S_AH_K
# Predict: HH_AR_T_S_T_AH_K
#
# +++++++++
# Word: SAFLEY
# Original: S_AE_F_L_IY
# Predict: S_AE_F_L_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: MONCADA
# Original: M_OW_N_K_AA_D_AH
# Predict: M_AH_NG_K_AA_D_AH
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: MCWHIRT
# Original: M_AH_K_W_ER_T
# Predict: M_AH_K_W_ER_EH_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: AMOSS
# Original: AH_M_AO_S
# Predict: AE_M_OW_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: POVICH'S
# Original: P_OW_V_IH_CH_IH_Z
# Predict: P_AA_V_IH_S_IIH_S_
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: GRABAU
# Original: G_R_AE_B_AW
# Predict: G_R_AY_B_OW
#
# +++++++++
# Word: DESMITH
# Original: D_EH_S_M_IH_TH
# Predict: D_EH_S_M_IH_TH
#
# +++++++++
# Word: BOITANO
# Original: B_OY_T_AA_N_OW
# Predict: B_OY_T_AA_N_OW
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: UNDO
# Original: AH_N_D_UW
# Predict: AH_N_D_OW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: LAFLAM
# Original: L_AA_F_L_AE_M
# Predict: L_AE_F_AH_L_M
#
# +++++++++
# Word: KOOP
# Original: K_UW_P
# Predict: K_UW_P
#
# +++++++++
# Word: ROACHE
# Original: R_OW_CH
# Predict: R_OW_CH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: UNSOLVED
# Original: AH_N_S_AA_L_V_D
# Predict: AH_N_S_AH_V_AH_L_D
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 12
# Word: CONDITIONAL
# Original: K_AH_N_D_IH_SH_AH_N_AH_L
# Predict: K_AH_N_D_IH_SH_AH_N_AA_A__L
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: HARDIGREE
# Original: HH_AA_R_D_IH_G_R_IY
# Predict: HH_AA_R_D_IH_G_ER_EY
#
# +++++++++
# Word: BATHOLITH
# Original: B_AE_TH_AH_L_IH_TH
# Predict: B_AE_TH_AH_L_IH_TH
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 6
# Word: AMBROGIO
# Original: AE_M_B_R_OW_JH_IY_OW
# Predict: AE_M_B_OR_OY_OW
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: GRBAVICA
# Original: G_ER_B_AA_V_IH_K_AH
# Predict: G_R_AY_V_IH_S_AH
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 10
# Word: TECHNOLOGIES
# Original: T_EH_K_N_AA_L_AH_JH_IY_Z
# Predict: T_EH_K_SH_AH_L_AH_S_IH_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: BRIDESMAIDS'
# Original: B_R_AY_D_Z_M_EY_D_Z
# Predict: B_R_IY_D_M_EY_D_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: HEISBOURG
# Original: HH_AY_S_B_AO_R_G
# Predict: HH_AY_S_B_AA_R_G
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: EVADER
# Original: IH_V_EY_D_ER
# Predict: IH_V_AH_D_ER
#
# +++++++++
# Word: FOBEL'S
# Original: F_OW_B_AH_L_Z
# Predict: F_OW_B_AH_L_Z
#
# ---------
# Phonemes in original word: 14
# Phonemse in predicted word: 12
# Word: CRIMINALIZATION
# Original: K_R_IH_M_AH_N_AH_L_AH_Z_EY_SH_AH_N
# Predict: K_R_IY_M_IH_N_AE_L_EY_SH_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: ANTIQUE
# Original: AE_N_T_IY_K
# Predict: AE_N_T_AH_K_UW
#
# +++++++++
# Word: JUEL
# Original: JH_UW_L
# Predict: JH_UW_L
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: KULHANEK
# Original: K_AH_L_HH_AH_N_EH_K
# Predict: K_AH_L_HH_EH_N_IH_K
#
# +++++++++
# Word: PALFREY
# Original: P_AE_L_F_R_IY
# Predict: P_AE_L_F_R_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 10
# Word: TURBEVILLE
# Original: T_ER_B_V_IH_L
# Predict: T_ER_B_IH_V_AH_V_AH_L_
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: SOFAMOR
# Original: S_OW_F_AH_M_AO_R
# Predict: S_OW_F_AH_M_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: ULIN
# Original: Y_UW_L_IH_N
# Predict: Y_UL_IH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: RECOVERED
# Original: R_AH_K_AH_V_ER_D
# Predict: R_IY_K_AH_V_ER_D
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: DODGER
# Original: D_AA_JH_ER
# Predict: D_AA_G_ER
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MATASSA
# Original: M_AA_T_AA_S_AH
# Predict: M_AH_T_AA_S_AH
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: MITTELSTADT
# Original: M_IH_T_IH_L_SH_T_AE_T
# Predict: M_IH_T_AH_L_AH_S_T
#
# +++++++++
# Word: CLUES
# Original: K_L_UW_Z
# Predict: K_L_UW_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: OCCURRED
# Original: AH_K_ER_D
# Predict: AO_K_E__R_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: REALIST
# Original: R_IY_AH_L_IH_S_T
# Predict: R_IY_L_IH_S_T
#
# +++++++++
# Word: DECENCY
# Original: D_IY_S_AH_N_S_IY
# Predict: D_IY_S_AH_N_S_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CATTANI
# Original: K_AA_T_AA_N_IY
# Predict: K_AH_T_AA_N_IY
#
# +++++++++
# Word: CLOE
# Original: K_L_OW
# Predict: K_L_OW
#
# +++++++++
# Word: JOKED
# Original: JH_OW_K_T
# Predict: JH_OW_K_T
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SOBON
# Original: S_OW_B_AO_N
# Predict: S_AA_B_AA_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: AUTOCRATIC
# Original: AO_T_AH_K_R_AE_T_IH_K
# Predict: AO_T_AH_R_AH_T_IH_K
#
# +++++++++
# Word: GERALDS
# Original: JH_EH_R_AH_L_D_Z
# Predict: JH_EH_R_AH_L_D_Z
#
# +++++++++
# Word: DANER
# Original: D_EY_N_ER
# Predict: D_EY_N_ER
#
# ---------
# Phonemes in original word: 15
# Phonemse in predicted word: 15
# Word: INTELLECTUALISM
# Original: IH_N_T_EH_L_AH_K_CH_UW_AH_L_IH_Z_AH_M
# Predict: IH_N_T_IH_K_W_IY_M_AH_L_IH_Z_AH_M_Z
#
# +++++++++
# Word: FORTMAN
# Original: F_AO_R_T_M_AH_N
# Predict: F_AO_R_T_M_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: NOBLER
# Original: N_OW_B_L_ER
# Predict: N_OA_B_AH_L_ER
#
# +++++++++
# Word: TAMPS
# Original: T_AE_M_P_S
# Predict: T_AE_M_P_S
#
# +++++++++
# Word: GREED
# Original: G_R_IY_D
# Predict: G_R_IY_D
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: SENTENCING
# Original: S_EH_N_T_AH_N_S_IH_NG
# Predict: S_EH_N_T_EY_S_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: DATAREX
# Original: D_EY_T_ER_EH_K_S
# Predict: D_AY_T_AA_R_IH_K_S
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 7
# Word: GERRYMANDER
# Original: JH_EH_R_IY_M_AE_N_D_ER
# Predict: JH_EH_IIM_M_EE_N_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HEIKEN
# Original: HH_AY_K_AH_N
# Predict: HH_EY_K_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: PYRAMID
# Original: P_IH_R_AH_M_IH_D
# Predict: P_IH_R_AM_AH_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: NOURISHING
# Original: N_ER_IH_SH_IH_NG
# Predict: N_AH_R_IH_SH_IH_NG
#
# +++++++++
# Word: PORDY
# Original: P_AO_R_D_IY
# Predict: P_AO_R_D_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: COUSY
# Original: K_UW_Z_IY
# Predict: K_AW_S_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: BYERLEIN
# Original: B_AY_R_L_AY_N
# Predict: B_AY_ER_L_IY_N
#
# +++++++++
# Word: WHIZ
# Original: W_IH_Z
# Predict: W_IH_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: RADANT
# Original: R_AA_D_AH_N_T
# Predict: R_AY_D_AE_N_T
#
# +++++++++
# Word: ELDRIDA
# Original: EH_L_D_R_IY_D_AH
# Predict: EH_L_D_R_IY_D_AH
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 11
# Word: SEPARATENESS
# Original: S_EH_P_ER_AH_T_N_AH_S
# Predict: S_EY_P_EH_R_EH_T__H_N_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: PERSUASIVE
# Original: P_ER_S_W_EY_S_IH_V
# Predict: P_ER_S_UW_V_IY_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: KILLINGBECK
# Original: K_IH_L_IH_NG_B_EH_K
# Predict: K_IH_L_IH_NGN_B_IH_K
#
# +++++++++
# Word: RITACCO
# Original: R_IY_T_AA_K_OW
# Predict: R_IY_T_AA_K_OW
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: SENIOR
# Original: S_IY_N_Y_ER
# Predict: S_EH_N_Y_EH_R
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: OVERJOYED
# Original: OW_V_ER_JH_OY_D
# Predict: OW_V_ER_G_A__D
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 6
# Word: LIKELIHOOD
# Original: L_AY_K_L_IY_HH_UH_D
# Predict: L_IY_K_L_IY_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CIMINO
# Original: CH_IY_M_IY_N_OW
# Predict: CH_IH_M_IH_N_OW
#
# +++++++++
# Word: KOPPLE
# Original: K_AA_P_AH_L
# Predict: K_AA_P_AH_L
#
# +++++++++
# Word: FLASHERS
# Original: F_L_AE_SH_ER_Z
# Predict: F_L_AE_SH_ER_Z
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: CHI'S
# Original: K_AY_Z
# Predict: CH_IY_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: EXCELLENCY
# Original: EH_K_S_L_EH_N_S_IY
# Predict: EH_K_S_AH_L_AH_N_S_IY
#
# +++++++++
# Word: PRITCHARD
# Original: P_R_IH_CH_ER_D
# Predict: P_R_IH_CH_ER_D
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: OSAKE
# Original: OW_S_AA_K_IY
# Predict: AW_S_AY_K
#
# +++++++++
# Word: MELLISH
# Original: M_EH_L_IH_SH
# Predict: M_EH_L_IH_SH
#
# +++++++++
# Word: KNUCKLE
# Original: N_AH_K_AH_L
# Predict: N_AH_K_AH_L
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: SADDLEBAG
# Original: S_AE_D_AH_L_B_AE_G
# Predict: S_AE_D_AH_L_AE_G
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: NABOBS
# Original: N_AE_B_AA_B_Z
# Predict: N_AY_B_AO_Z
#
# +++++++++
# Word: CAYSON
# Original: K_EY_S_AH_N
# Predict: K_EY_S_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: BETRAYS
# Original: B_IH_T_R_EY_Z
# Predict: B_EH_T_R_EY_Z
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 10
# Word: QUALITATIVELY
# Original: K_W_AA_L_AH_T_EY_T_IH_V_L_IY
# Predict: K_W_AH_L_IH_T_IH_V_L_IY
#
# +++++++++
# Word: FREEWAYS
# Original: F_R_IY_W_EY_Z
# Predict: F_R_IY_W_EY_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: HOLT
# Original: HH_OW_L_T
# Predict: HH_OA_L_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: APPLEBAUM
# Original: AE_P_AH_L_B_AW_M
# Predict: AE_P_L_AH_B_AW_M
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: UNADJUSTED
# Original: AH_N_AH_JH_AH_S_T_IH_D
# Predict: AH_N_AH_JH_UW_S_T__D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: JOSSELYN
# Original: JH_AA_S_IH_L_IH_N
# Predict: JH_AA_S_AH_L_IY_N
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: EYRIE
# Original: EH_R_IY
# Predict: EY_E__Y
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 8
# Word: STRZELECKI
# Original: S_T_R_EH_Z_IH_L_EH_T_S_K_IY
# Predict: S_T_R_EH_L_EH_K_IY
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: LIBRARIAN
# Original: L_AY_B_R_EH_R_IY_AH_N
# Predict: L_IY_B_R_EY_R_IY_AH_N
#
# +++++++++
# Word: HORGAN
# Original: HH_AO_R_G_AH_N
# Predict: HH_AO_R_G_AH_N
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: HELPLESSNESS
# Original: HH_EH_L_P_L_AH_S_N_AH_S
# Predict: HH_EH_L_P_L_AH_N_IH_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: LARZELERE
# Original: L_ER_Z_EH_L_ER
# Predict: L_AA_R_Z_IH_L_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SCIULLI
# Original: S_IY_UW_L_IY
# Predict: S_K_AY_L_IY
#
# +++++++++
# Word: FITNESS
# Original: F_IH_T_N_AH_S
# Predict: F_IH_T_N_AH_S
#
# +++++++++
# Word: PAYMER
# Original: P_EY_M_ER
# Predict: P_EY_M_ER
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 11
# Word: EXPIRATORY
# Original: IH_K_S_P_AY_R_AH_T_AO_R_IY
# Predict: EH_K_S_P_IY_R__Y_T__Y
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HIEBERT
# Original: HH_IY_B_ER_T
# Predict: HH_AY_B_ER_T
#
# +++++++++
# Word: STRAM
# Original: S_T_R_AE_M
# Predict: S_T_R_AE_M
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: DISORDERLY
# Original: D_IH_S_AO_R_D_ER_L_IY
# Predict: D_IH_S_AO_R_IH_L_D_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: SQUASH
# Original: S_K_W_AA_SH
# Predict: S_K_W_AA_SH_AH
#
# +++++++++
# Word: MELLIE
# Original: M_EH_L_IY
# Predict: M_EH_L_IY
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 10
# Word: CRASNIANSKI
# Original: K_R_AE_S_N_IY_AE_N_S_K_IY
# Predict: K_R_AE_SH_IH_N_AH_S_K_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: LONGMORE
# Original: L_OW_NG_M_AO_R
# Predict: L_AO_NG_G_M_EO_R
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: HILLENBURG
# Original: HH_IH_L_AH_N_B_ER_G
# Predict: HH_IH_L_IH_NG_B_ER_G_
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: CAVIAR
# Original: K_AE_V_IY_AA_R
# Predict: K_AH_V_IY_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 7
# Word: KOHNEN
# Original: K_OW_N_AH_N
# Predict: K_OW_N__H_AH_N
#
# +++++++++
# Word: I
# Original: AY
# Predict: AY
#
# +++++++++
# Word: KNOB
# Original: N_AA_B
# Predict: N_AA_B
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: MERCHANTS
# Original: M_ER_CH_AH_N_T_S
# Predict: M_ER_KHAA_AN_T_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: LIVOTI
# Original: L_IY_V_OW_T_IY
# Predict: L_IY_V_OA_T_IY
#
# +++++++++
# Word: KUNKEL
# Original: K_AH_NG_K_AH_L
# Predict: K_AH_NG_K_AH_L
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: BROWSERS
# Original: B_R_AW_Z_ER_Z
# Predict: B_R_OW_Z_ER_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: WANGLER
# Original: W_AE_NG_G_L_ER
# Predict: W_AO_NG_G_L_ER
#
# +++++++++
# Word: RICK
# Original: R_IH_K
# Predict: R_IH_K
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: MICROWAVE
# Original: M_AY_K_R_AH_W_EY_V
# Predict: M_IH_K_R_OW_V_EY
#
# +++++++++
# Word: MIDPAC
# Original: M_IH_D_P_AE_K
# Predict: M_IH_D_P_AE_K
#
# +++++++++
# Word: HEILAND
# Original: HH_AY_L_AH_N_D
# Predict: HH_AY_L_AH_N_D
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MAZEL
# Original: M_AH_Z_AH_L
# Predict: M_AE_Z_AH_L
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 7
# Word: DIONYSIUS
# Original: D_AY_AH_N_IH_S_IY_AH_S
# Predict: D_AY_AH_N_IY_AH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: FLEURETTE
# Original: F_L_ER_EH_T
# Predict: F_L_ER_ER_EH_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: TOMATOES
# Original: T_AH_M_EY_T_OW_Z
# Predict: T_AA_M_EH_T_OW_Z
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 9
# Word: EVENTUALITY
# Original: AH_V_EH_N_CH_UW_AE_L_IH_T_IY
# Predict: EY_V_EH_N_Y_UW_AH_L_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SHELLACKED
# Original: SH_EH_L_AE_K_D
# Predict: SH_EH_L_AH_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 8
# Word: BEGUILED
# Original: B_IH_G_AY_L_D
# Predict: B_IH_G_W__H_L_D
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: OVERPRODUCED
# Original: OW_V_ER_P_R_AH_D_UW_S_T
# Predict: OW_V_ER_P_R_UH_P_UW_D
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SOBIL'S
# Original: S_OW_B_AH_L_Z
# Predict: S_OY_B_AH_L_Z
#
# +++++++++
# Word: ANALYST
# Original: AE_N_AH_L_IH_S_T
# Predict: AE_N_AH_L_IH_S_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: OUTRIGGER
# Original: AW_T_R_IH_G_ER
# Predict: AW_T_R_IY_G_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: ZALOUDEK
# Original: Z_AE_L_AW_D_IH_K
# Predict: Z_AH_L_AW_D_IH_K
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: CANCAN
# Original: K_AE_N_K_AE_N
# Predict: K_AE_N_K_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: BUILTIN
# Original: B_IH_L_T_IH_N
# Predict: B_AY_L_T_IH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: OMNISCIENT
# Original: AA_M_N_IH_SH_AH_N_T
# Predict: AA_M_N_IH_S_SHAAH_N_AH_T
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: TECTONIC
# Original: T_EH_K_T_AA_N_IH_K
# Predict: T_EH_K_T_AH_N_IH_K
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: POSTNATAL
# Original: P_OW_S_T_N_EY_T_AH_L
# Predict: P_AH_S_T_AE_N_T_AA_L_A
#
# +++++++++
# Word: FARNES
# Original: F_AA_R_N_Z
# Predict: F_AA_R_N_Z
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 4
# Word: BAHRE
# Original: B_AA_R
# Predict: B_AA_R_AH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: ALLEGIANCE
# Original: AH_L_IY_JH_AH_N_S
# Predict: AE_L_IH_G_AY_N_S_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: ADRIANCE
# Original: AA_D_R_IY_AH_N_S
# Predict: AH_D_R_IY_AH_N_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: BEEN
# Original: B_IH_N
# Predict: B_IY_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: LEMOINE
# Original: L_IH_M_OY_N
# Predict: L_IH_M_OW_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: FICHUS
# Original: F_IH_CH_AH_S
# Predict: F_IY_CH_AH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: FELIX'S
# Original: F_IY_L_IH_K_S_IH_Z
# Predict: F_EH_L_IH_K_S_IH_Z
#
# +++++++++
# Word: CLIFFORD'S
# Original: K_L_IH_F_ER_D_Z
# Predict: K_L_IH_F_ER_D_Z
#
# +++++++++
# Word: KOZLOFF
# Original: K_AA_Z_L_AO_F
# Predict: K_AA_Z_L_AO_F
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: MACEWEN
# Original: M_AH_K_Y_UW_AA_N
# Predict: M_EY_S_W_EY_N
#
# +++++++++
# Word: LEFFERTS
# Original: L_EH_F_ER_T_S
# Predict: L_EH_F_ER_T_S
#
# +++++++++
# Word: BODKIN
# Original: B_AA_D_K_IH_N
# Predict: B_AA_D_K_IH_N
#
# +++++++++
# Word: IMPROV
# Original: IH_M_P_R_AA_V
# Predict: IH_M_P_R_AA_V
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: KONDRACKI
# Original: K_AH_N_D_R_AA_T_S_K_IY
# Predict: K_AH_N_D_R_AE_R_K_IY
#
# +++++++++
# Word: SATURATE
# Original: S_AE_CH_ER_EY_T
# Predict: S_AE_CH_ER_EY_T
#
# +++++++++
# Word: STRASBURGER
# Original: S_T_R_AE_S_B_ER_G_ER
# Predict: S_T_R_AE_S_B_ER_G_ER
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: METROPOL'S
# Original: M_EH_T_R_AH_P_OW_L_Z
# Predict: M_EH_T_R_AH_P_A__L_Z
#
# +++++++++
# Word: BAGEL
# Original: B_EY_G_AH_L
# Predict: B_EY_G_AH_L
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: MULTICOLOR
# Original: M_AH_L_T_IY_K_AH_L_ER
# Predict: M_AH_L_T_IH_K_L__R_R
#
# +++++++++
# Word: MOBSTER'S
# Original: M_AA_B_S_T_ER_Z
# Predict: M_AA_B_S_T_ER_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: HORSEPOWER
# Original: HH_AO_R_S_P_AW_ER
# Predict: HH_AO_R_S_P_EH_R_ER
#
# +++++++++
# Word: RAWLS
# Original: R_AO_L_Z
# Predict: R_AO_L_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SUDDARTH
# Original: S_AH_D_AA_R_TH
# Predict: S_AH_D_ER_AH_CH
#
# +++++++++
# Word: REMPEL
# Original: R_EH_M_P_AH_L
# Predict: R_EH_M_P_AH_L
#
# +++++++++
# Word: TOMASI
# Original: T_OW_M_AA_S_IY
# Predict: T_OW_M_AA_S_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: JAMBOR
# Original: Y_AA_M_B_AO_R
# Predict: JH_AE_M_B_EO_R
#
# +++++++++
# Word: SNUGGING
# Original: S_N_AH_G_IH_NG
# Predict: S_N_AH_G_IH_NG
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: TROPEANO
# Original: T_R_OW_P_IY_N_OW
# Predict: T_R_OA_P_IY_N_OW
#
# +++++++++
# Word: HAP
# Original: HH_AE_P
# Predict: HH_AE_P
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: UPSTAGE
# Original: AH_P_S_T_EY_JH
# Predict: AH_P_S_T_EH_JH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: HYUNDAIS
# Original: HH_Y_AH_N_D_EY_Z
# Predict: HH_Y_AY_D_N_AY_Z
#
# +++++++++
# Word: FEASTS
# Original: F_IY_S_T_S
# Predict: F_IY_S_T_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: KNUDSEN
# Original: K_N_UW_D_S_AH_N
# Predict: N_AH_D_S_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: WHITEWASH
# Original: W_AY_T_W_AA_SH
# Predict: W_IY_TH_W_ESH_AH_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: LILY
# Original: L_IH_L_IY
# Predict: L_IY_L_IY
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: ORIGIN
# Original: AO_R_AH_JH_AH_N
# Predict: AO_R_IH_G_AH_N
#
# +++++++++
# Word: GASSERT
# Original: G_AE_S_ER_T
# Predict: G_AE_S_ER_T
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 10
# Word: MODIFICATIONS
# Original: M_AA_D_AH_F_AH_K_EY_SH_AH_N_Z
# Predict: M_OH_D_AH_F_EY_SH_AH_N_Z
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 9
# Word: COMPOSITIONS
# Original: K_AA_M_P_AH_Z_IH_SH_AH_N_Z
# Predict: K_AH_M_P_AH_SH_AH_N_Z
#
# +++++++++
# Word: STAYS
# Original: S_T_EY_Z
# Predict: S_T_EY_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: RYBAKOV
# Original: R_AY_B_AH_K_AA_V
# Predict: R_IY_AEAB_A__K_AO_V
#
# +++++++++
# Word: NANKING
# Original: N_AE_NG_K_IH_NG
# Predict: N_AE_NG_K_IH_NG
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MORPHINE
# Original: M_AO_R_F_IY_N
# Predict: M_AO_R_F_AY_N
#
# +++++++++
# Word: PROPERTIES
# Original: P_R_AA_P_ER_T_IY_Z
# Predict: P_R_AA_P_ER_T_IY_Z
#
# +++++++++
# Word: FOUNDERED
# Original: F_AW_N_D_ER_D
# Predict: F_AW_N_D_ER_D
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: REPLIGEN
# Original: R_IH_P_L_AY_JH_IH_N
# Predict: R_EH_P_L_IH_JH_AH_N
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HEATHROW
# Original: HH_IY_TH_R_OW
# Predict: HH_EY_TH_R_OW
#
# +++++++++
# Word: KOSSOW
# Original: K_AA_S_OW
# Predict: K_AA_S_OW
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: BASTARACHE
# Original: B_AA_S_T_AA_R_EY_K
# Predict: B_AE_S_T_ER_EY_K
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: BROSIUS
# Original: B_R_OW_S_IY_IH_S
# Predict: B_R_OW_S_IY_AH_S
#
# +++++++++
# Word: HOPPERT
# Original: HH_AA_P_ER_T
# Predict: HH_AA_P_ER_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 3
# Word: MERWE
# Original: M_ER_W_IY
# Predict: M_ER_W
#
# +++++++++
# Word: STAMLER
# Original: S_T_AE_M_L_ER
# Predict: S_T_AE_M_L_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: ELCOTEL
# Original: EH_L_K_OW_T_EH_L
# Predict: EH_L_K_AA_T_AH_L_
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: PALACIO
# Original: P_AH_L_EY_S_IY_OW
# Predict: P_AA_L_AA_S__Y_OW
#
# +++++++++
# Word: HILTONS
# Original: HH_IH_L_T_AH_N_Z
# Predict: HH_IH_L_T_AH_N_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: EXHUMES
# Original: EH_K_S_HH_Y_UW_M_Z
# Predict: EH_K_SH_H__M_UW_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: STEVESON
# Original: S_T_EH_V_IH_S_AH_N
# Predict: S_T_EH_V_AH_S_AH_N
#
# +++++++++
# Word: SCHUM
# Original: SH_AH_M
# Predict: SH_AH_M
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 6
# Word: BOWICK
# Original: B_OW_IH_K
# Predict: B_OW_I__H_K
#
# +++++++++
# Word: SCROOGE
# Original: S_K_R_UW_JH
# Predict: S_K_R_UW_JH
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 13
# Word: NON-STRATEGIC
# Original: N_AA_N_S_T_R_AH_T_IY_JH_IH_K
# Predict: N_AA_N_S_T_R_AE_T_IH_K_IH_K_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: LIBRETTO
# Original: L_IH_B_R_EH_T_OW
# Predict: L_IY_B_R_EH_T_OW
#
# +++++++++
# Word: PLENUM'S
# Original: P_L_EH_N_AH_M_Z
# Predict: P_L_EH_N_AH_M_Z
#
# +++++++++
# Word: SUSTAINS
# Original: S_AH_S_T_EY_N_Z
# Predict: S_AH_S_T_EY_N_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: ADDED
# Original: AE_D_IH_D
# Predict: AE_D_AH_D
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: CHASES
# Original: CH_EY_S_AH_Z
# Predict: CH_AY_Z_AH_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: LONARDO
# Original: L_OW_N_AA_R_D_OW
# Predict: L_AW_N_AA_R_D_OW
#
# +++++++++
# Word: SPINK
# Original: S_P_IH_NG_K
# Predict: S_P_IH_NG_K
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: AMPLIFYING
# Original: AE_M_P_L_AH_F_AY_IH_NG
# Predict: AE_M_P_L_AY_F_IH_NG
#
# +++++++++
# Word: RAILROADS
# Original: R_EY_L_R_OW_D_Z
# Predict: R_EY_L_R_OW_D_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: HARTNETT
# Original: HH_AA_R_T_N_IH_T
# Predict: HH_AA_R_N_TH_H_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 4
# Word: SACHS'S
# Original: S_AE_K_S_IH_Z
# Predict: S_AE_K_S
#
# +++++++++
# Word: ABBASI
# Original: AA_B_AA_S_IY
# Predict: AA_B_AA_S_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: MUNNI
# Original: M_Y_UW_N_IY
# Predict: M_AH_N_IY
#
# +++++++++
# Word: AMTECH
# Original: AE_M_T_EH_K
# Predict: AE_M_T_EH_K
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: LABARR
# Original: L_AH_B_AE_R
# Predict: L_AY_B_AA_R
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: MOLPUS
# Original: M_AO_L_P_AH_S
# Predict: M_OW_L_P_AH_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: JUNGHANS
# Original: JH_AH_NG_G_AH_N_Z
# Predict: JH_AH_N_HH_AH_N_Z
#
# +++++++++
# Word: TEMEROUS
# Original: T_EH_M_ER_AH_S
# Predict: T_EH_M_ER_AH_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: ANIMISM
# Original: AE_N_AH_M_IH_Z_AH_M
# Predict: AE_N_IH_M_IH_Z_AH_M
#
# +++++++++
# Word: VENDETTA
# Original: V_EH_N_D_EH_T_AH
# Predict: V_EH_N_D_EH_T_AH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: HALLOWELL
# Original: HH_AE_L_AH_W_EH_L
# Predict: HH_AE_L_OW_L_
#
# +++++++++
# Word: LETH
# Original: L_EH_TH
# Predict: L_EH_TH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: LINOTYPE
# Original: L_IH_N_OW_T_AY_P
# Predict: L_IY_N_AH_P_IY_P
#
# +++++++++
# Word: HASHES
# ...
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: AVIV'S
# Original: AA_V_IY_V_Z
# Predict: AY_V_IH_V_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: PODOLSKI
# Original: P_AH_D_OW_L_S_K_IY
# Predict: P_OH_D_AH_L_S_K_IY
#
# +++++++++
# Word: SHETTERLY
# Original: SH_EH_T_ER_L_IY
# Predict: SH_EH_T_ER_L_IY
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: DRYPOINT
# Original: D_R_AY_P_OY_N_T
# Predict: D_R_IY_P_OW_N_TN_T
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: PLATFORMS
# Original: P_L_AE_T_F_AO_R_M_Z
# Predict: P_L_AE_T_F_ER_M_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: REFUND
# Original: R_IH_F_AH_N_D
# Predict: R_IY_F_AH_N_D
#
# +++++++++
# Word: HELSER
# Original: HH_EH_L_S_ER
# Predict: HH_EH_L_S_ER
#
# +++++++++
# Word: SEAMS
# Original: S_IY_M_Z
# Predict: S_IY_M_Z
#
# +++++++++
# Word: MELLOAN
# Original: M_EH_L_OW_N
# Predict: M_EH_L_OW_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: SCHIAVO'S
# Original: S_K_IY_AA_V_OW_Z
# Predict: SH_IY_AH_V_OW_Z
#
# +++++++++
# Word: OLAY
# Original: OW_L_EY
# Predict: OW_L_EY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: MOLLOY
# Original: M_AA_L_OY
# Predict: M_OA_L_OY
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: MISMANAGES
# Original: M_IH_S_M_AE_N_IH_JH_AH_Z
# Predict: M_IH_S_M_AH_N_JH_IH_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: TYPO
# Original: T_AY_P_OW
# Predict: T_IY_P_OW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: THICKNESS
# Original: TH_IH_K_N_AH_S
# Predict: DH_IH_K_N_AH_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: DAHLEN
# Original: D_AA_L_AH_N
# Predict: D_AE_L_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: DOMINUS
# Original: D_OW_M_IY_N_AH_S
# Predict: D_AA_M_IH_N_AW_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MARAN
# Original: M_AA_R_AA_N
# Predict: M_EH_R_AH_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: HYPERION
# Original: HH_AY_P_IH_R_IY_AH_N
# Predict: HH_AY_P_ER_IY_SH_AH_N
#
# +++++++++
# Word: LEK
# Original: L_EH_K
# Predict: L_EH_K
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: AUTOMATIC
# Original: AO_T_AH_M_AE_T_IH_K
# Predict: AO_T_AH_M_AH_T_IH_K
#
# ---------
# Phonemes in original word: 13
# Phonemse in predicted word: 11
# Word: METROPOLITAN'S
# Original: M_EH_T_R_AH_P_AA_L_AH_T_AH_N_Z
# Predict: M_EH_T_R_AH_P_AH_L_EH_N_Z
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 10
# Word: SLOVAKIAN
# Original: S_L_OW_V_AA_K_IY_AH_N
# Predict: S_L_AW_V_AH_S__AH_N_
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: EXTANT
# Original: EH_K_S_T_AH_N_T
# Predict: IH_K_S_T_AE_N_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: YONA
# Original: Y_OW_N_AH
# Predict: Y_OH_N_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: MEISSNER
# Original: M_AY_S_N_ER
# Predict: M_AY_S_N_EY_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 6
# Word: VANHORNE
# Original: V_AE_N_HH_AO_R_N
# Predict: V_AE_N_HH_EO_R
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: BICEPS
# Original: B_AY_S_EH_P_S
# Predict: B_AY_AH_P_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: PENNSAUKEN
# Original: P_EH_N_S_AO_K_AH_N
# Predict: P_EH_N_S_UH_P_AH_N
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: MORENO
# Original: M_AO_R_IY_N_OW
# Predict: M_AO_RY_N_OW
#
# +++++++++
# Word: PISTOLE
# Original: P_IH_S_T_OW_L
# Predict: P_IH_S_T_OW_L
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 7
# Word: SENIORS
# Original: S_IY_N_Y_ER_Z
# Predict: S_EH_N_Y_AH_R_Z
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: REBUILDER
# Original: R_IY_B_IH_L_D_ER
# Predict: R_IY_B_IH_D_EH_L_ER
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: GARCIA
# Original: G_AA_R_S_IY_AH
# Predict: G_AA_R_SH_AH
#
# +++++++++
# Word: SITKO
# Original: S_IH_T_K_OW
# Predict: S_IH_T_K_OW
#
# +++++++++
# Word: BRUCK'S
# Original: B_R_AH_K_S
# Predict: B_R_AH_K_S
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: NOWLAND
# Original: N_AW_L_AH_N_D
# Predict: N_AW_L_AE_N_D
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: DASCENZO
# Original: D_AA_S_CH_EH_N_Z_OW
# Predict: D_AE_S_CH_EH_N_Z_OW
#
# +++++++++
# Word: STARRED
# Original: S_T_AA_R_D
# Predict: S_T_AA_R_D
#
# +++++++++
# Word: GERM
# Original: JH_ER_M
# Predict: JH_ER_M
#
# +++++++++
# Word: ROYLE
# Original: R_OY_L
# Predict: R_OY_L
#
# +++++++++
# Word: HESIK
# Original: HH_EH_S_IH_K
# Predict: HH_EH_S_IH_K
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: HORNBLOWER
# Original: HH_AO_R_N_B_L_OW_ER
# Predict: HH_AO_R_N_B_AH_L_EWEER
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: STEINBORN
# Original: S_T_AY_N_B_AO_R_N
# Predict: S_T_AY_N_B_AO_R
#
# +++++++++
# Word: PLEADINGS
# Original: P_L_IY_D_IH_NG_Z
# Predict: P_L_IY_D_IH_NG_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: ACKHOUSE
# Original: AE_K_HH_AW_S
# Predict: AE_K_HH_AW_Z
#
# +++++++++
# Word: MCKIM
# Original: M_AH_K_IH_M
# Predict: M_AH_K_IH_M
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: ANACKER
# Original: AE_N_AH_K_ER
# Predict: AE_N_AY_K_ER
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 3
# Word: ULA
# Original: Y_UW_L_AH
# Predict: AH_L_AH
#
# ---------
# Phonemes in original word: 12
# Phonemse in predicted word: 11
# Word: CONFLAGRATION
# Original: K_AA_N_F_L_AH_G_R_EY_SH_AH_N
# Predict: K_AH_NG_F_L_EE_R_EY_SH_AH_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: LIFE-CHANGING
# Original: L_AY_F_CH_EY_N_JH_IH_NG
# Predict: L_IY_F_EH_K_EE_NGN_IH_NG
#
# +++++++++
# Word: UGLIEST
# Original: AH_G_L_IY_AH_S_T
# Predict: AH_G_L_IY_AH_S_T
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 5
# Word: ISLAS
# Original: AY_L_AH_Z
# Predict: IH_S_L_AH_Z
#
# +++++++++
# Word: BAITS
# Original: B_EY_T_S
# Predict: B_EY_T_S
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: DYNEER
# Original: D_IH_N_IH_R
# Predict: D_AY_N_EY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: NOSY
# Original: N_OW_Z_IY
# Predict: N_OY_Z_IY
#
# +++++++++
# Word: DEALY
# Original: D_IY_L_IY
# Predict: D_IY_L_IY
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HOLAN
# Original: HH_OW_L_AH_N
# Predict: HH_OA_L_AH_N
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 11
# Word: PROSECUTORS
# Original: P_R_AA_S_IH_K_Y_UW_T_ER_Z
# Predict: P_R_OW_S_IH_K_Y_ER_T_ER_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: EDWARD
# Original: EH_D_W_ER_D
# Predict: EH_D_W_EO_R_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: FREDERIC
# Original: F_R_EH_D_R_IH_K
# Predict: F_R_EH_D_EH_R_IH_K
#
# +++++++++
# Word: PATCHING
# Original: P_AE_CH_IH_NG
# Predict: P_AE_CH_IH_NG
#
# +++++++++
# Word: CRISPY
# Original: K_R_IH_S_P_IY
# Predict: K_R_IH_S_P_IY
#
# +++++++++
# Word: PLATTS
# Original: P_L_AE_T_S
# Predict: P_L_AE_T_S
#
# +++++++++
# Word: PENTZ
# Original: P_EH_N_T_S
# Predict: P_EH_N_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: COTTA
# Original: K_AA_T_AH
# Predict: K_OH_T_AH
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: BLACKEST
# Original: B_L_AE_K_AH_S_T
# Predict: B_L_AE_S_IH_S_TH_T
#
# +++++++++
# Word: LEPPLA
# Original: L_EH_P_L_AH
# Predict: L_EH_P_L_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 6
# Word: IMPEACH
# Original: IH_M_P_IY_CH
# Predict: IH_M_P_IY_AH_K
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: CHELETTE
# Original: SH_IH_L_EH_T
# Predict: CH_EH_L_AH_T
#
# +++++++++
# Word: TOYED
# Original: T_OY_D
# Predict: T_OY_D
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 8
# Word: LITHUANIA'S
# Original: L_IH_TH_AH_W_EY_N_IY_AH_Z
# Predict: L_IH_TH_UW_N_IY_AH_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: KLOECKNER
# Original: K_L_OW_K_N_ER
# Predict: K_L_OW_N_S_ER
#
# +++++++++
# Word: DARMAN'S
# Original: D_AA_R_M_AH_N_Z
# Predict: D_AA_R_M_AH_N_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: DORSCH
# Original: D_AO_R_SH
# Predict: D_AO_R_CH
#
# +++++++++
# Word: DIRCKS
# Original: D_ER_K_S
# Predict: D_ER_K_S
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: ENSCONCE
# Original: IH_N_S_K_AA_N_S
# Predict: IH_N_S_AA_N_S_AH_N
#
# +++++++++
# Word: JUDSEN
# Original: JH_AH_D_S_AH_N
# Predict: JH_AH_D_S_AH_N
#
# +++++++++
# Word: COILING
# Original: K_OY_L_IH_NG
# Predict: K_OY_L_IH_NG
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 9
# Word: ANALYTICITY
# Original: AE_N_AH_L_AH_T_IH_S_AH_T_IY
# Predict: AE_N_AH_L_AH_T_IY_T_IY
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: COMBED
# Original: K_OW_M_D
# Predict: K_AH_M_D
#
# ---------
# Phonemes in original word: 14
# Phonemse in predicted word: 12
# Word: PROGNOSTICATED
# Original: P_R_AA_G_N_AA_S_T_AH_K_EY_T_IH_D
# Predict: P_R_AA_NG___AH_S_IH_T_IH_D
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: TITANIC
# Original: T_AY_T_AE_N_IH_K
# Predict: T_AY_TH_E_N_IH_K
#
# +++++++++
# Word: MUTCH
# Original: M_AH_CH
# Predict: M_AH_CH
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: NIES
# Original: N_AY_Z
# Predict: N_IY_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: DONOHO
# Original: D_AA_N_AH_HH_OW
# Predict: D_AA_N_AH_OW
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 4
# Word: FICHERA
# Original: F_IY_K_EH_R_AH
# Predict: F_IH_KHER_AH
#
# +++++++++
# Word: MILNER
# Original: M_IH_L_N_ER
# Predict: M_IH_L_N_ER
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: JOHNSTONE
# Original: JH_AA_N_S_T_OW_N
# Predict: JH_AA_N_S_T_AY_N
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 8
# Word: LOGOTHETIS
# Original: L_OW_G_OW_TH_EH_T_IH_S
# Predict: L_AA_G_AH_EH_T_IY_S
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: KYL
# Original: K_AY_L
# Predict: K_IY_L
#
# +++++++++
# Word: MCKAIN
# Original: M_AH_K_EY_N
# Predict: M_AH_K_EY_N
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 7
# Word: DISPROVED
# Original: D_IH_S_P_R_UW_V_D
# Predict: D_IH_S_P_R_AH_V
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: AVERAGED
# Original: AE_V_R_IH_JH_D
# Predict: AH_V_ER_AH_G_D
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: NULLIFYING
# Original: N_AH_L_AH_F_AY_IH_NG
# Predict: N_AH_L_AH_F_IY_N_ING
#
# +++++++++
# Word: KRAFT
# Original: K_R_AE_F_T
# Predict: K_R_AE_F_T
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: ROSINA
# Original: R_OW_Z_IY_N_AH
# Predict: R_OW_S_IH_N_AH
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HEIFERS
# Original: HH_EH_F_ER_Z
# Predict: HH_AY_F_ER_Z
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: HIRED
# Original: HH_AY_ER_D
# Predict: HH_AY_E_D
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: SHERTZER
# Original: SH_ER_T_Z_ER
# Predict: SH_ER_T_ER
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 4
# Word: BUDER
# Original: B_Y_UW_D_ER
# Predict: B_AH_D_ER
#
# ---------
# Phonemes in original word: 11
# Phonemse in predicted word: 10
# Word: TRANSFORMERS
# Original: T_R_AE_N_S_F_AO_R_M_ER_Z
# Predict: T_R_AE_N_S_AO_F_ER_ZR_Z
#
# +++++++++
# Word: BRAND'S
# Original: B_R_AE_N_D_Z
# Predict: B_R_AE_N_D_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: HARIRI
# Original: HH_ER_IH_R_IY
# Predict: HH_EH_R_IY_IY
#
# +++++++++
# Word: DWORSKY
# Original: D_W_ER_S_K_IY
# Predict: D_W_ER_S_K_IY
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: SPANDEX
# Original: S_P_AE_N_D_AH_K_S
# Predict: S_P_AE_N_D_EH_K_S
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: MISSISSAUGA
# Original: M_IH_S_IH_S_AO_G_AH
# Predict: M_IH_S_IH_G_A__S_AA
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: GYROSCOPIC
# Original: JH_AY_R_AH_S_K_AA_P_IH_K
# Predict: JH_AH_R_A__P_A__K
#
# +++++++++
# Word: LENGEL
# Original: L_EH_NG_G_AH_L
# Predict: L_EH_NG_G_AH_L
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: SARAH'S
# Original: S_EH_R_AH_Z
# Predict: S_AH_R_AH_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: DONATE
# Original: D_OW_N_EY_T
# Predict: D_AA_N_AY_T
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: SCIENCES
# Original: S_AY_AH_N_S_AH_Z
# Predict: S_AY_AH_N_S_IH_Z
#
# +++++++++
# Word: INVESTOR'S
# Original: IH_N_V_EH_S_T_ER_Z
# Predict: IH_N_V_EH_S_T_ER_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 9
# Word: TARGETED
# Original: T_AA_R_G_AH_T_IH_D
# Predict: T_AA_R_G_IH_T__H_D
#
# ---------
# Phonemes in original word: 9
# Phonemse in predicted word: 9
# Word: RESEALABLE
# Original: R_IY_S_IY_L_AH_B_AH_L
# Predict: R_IY_Z_IY_AHAH_AH_L_AH_B
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 8
# Word: TATEHO'S
# Original: T_AH_T_EY_HH_OW_Z
# Predict: T_AE_TH_HH_O__W_Z
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: DEFORE
# Original: D_IY_F_AO_R
# Predict: D_IH_F_EO_R
#
# ---------
# Phonemes in original word: 13
# Phonemse in predicted word: 14
# Word: SUPERCONDUCTORS
# Original: S_UW_P_ER_K_AH_N_D_AH_K_T_ER_Z
# Predict: S_UW_P_ER_K_AH_D_AH_R_T_ER_Z_ER_Z
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 17
# Word: JARUZELSKI
# Original: JH_EH_R_AH_Z_EH_L_S_K_IY
# Predict: Y_AA__H__H_________Y_Y_
#
# +++++++++
# Word: STORE'S
# Original: S_T_AO_R_Z
# Predict: S_T_AO_R_Z
#
# +++++++++
# Word: PLENUM
# Original: P_L_EH_N_AH_M
# Predict: P_L_EH_N_AH_M
#
# +++++++++
# Word: TOOTE
# Original: T_UW_T
# Predict: T_UW_T
#
# ---------
# Phonemes in original word: 3
# Phonemse in predicted word: 3
# Word: NIESS
# Original: N_IY_S
# Predict: N_IY_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: PADLOCK
# Original: P_AE_D_L_AA_K
# Predict: P_AE_D_L_AH_K
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 3
# Word: KVAMME
# Original: K_AH_V_AE_M
# Predict: K_AY_M
#
# ---------
# Phonemes in original word: 5
# Phonemse in predicted word: 5
# Word: MAYTAG
# Original: M_EY_T_AE_G
# Predict: M_EY_T_AH_G
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: COUSIN'S
# Original: K_AH_Z_AH_N_Z
# Predict: K_AW_Z_AH_N_Z
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 5
# Word: BICHSEL
# Original: B_IH_K_S_AH_L
# Predict: B_IH_SH_AH_L
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: LOVER
# Original: L_AH_V_ER
# Predict: L_OW_V_ER
#
# +++++++++
# Word: WORSTELL
# Original: W_ER_S_T_AH_L
# Predict: W_ER_S_T_AH_L
#
# +++++++++
# Word: HOOTS
# Original: HH_UW_T_S
# Predict: HH_UW_T_S
#
# ---------
# Phonemes in original word: 4
# Phonemse in predicted word: 4
# Word: CLOWES
# Original: K_L_AW_Z
# Predict: K_L_OW_Z
#
# ---------
# Phonemes in original word: 8
# Phonemse in predicted word: 8
# Word: JACQUELINE
# Original: JH_AE_K_W_AH_L_IH_N
# Predict: JH_AE_K_W_AH_L_AH_N
#
# +++++++++
# Word: CANCUN
# Original: K_AE_NG_K_AH_N
# Predict: K_AE_NG_K_AH_N
#
# ---------
# Phonemes in original word: 7
# Phonemse in predicted word: 7
# Word: NEUGEBAUER
# Original: N_UW_G_AH_B_AW_ER
# Predict: N_UW_G_IH_B_ER_ER
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 8
# Word: PROSECUTOR
# Original: P_R_AA_S_IH_K_Y_UW_T_ER
# Predict: P_R_OW_S_IH_K_AH_R
#
# +++++++++
# Word: STIEBEL
# Original: S_T_IY_B_AH_L
# Predict: S_T_IY_B_AH_L
#
# ---------
# Phonemes in original word: 10
# Phonemse in predicted word: 9
# Word: FENSTERMAKER
# Original: F_EH_N_S_T_ER_M_EY_K_ER
# Predict: F_EH_N_S_T_M_EY_K_ER
#
# ---------
# Phonemes in original word: 6
# Phonemse in predicted word: 6
# Word: SIDDONS
# Original: S_IH_D_AH_N_Z
# Predict: S_IH_D_AO_N_Z
#
# Accuracy = 0.338

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > GEARED
# = G_IH_R_D
# < Z_EE__R_D
#
# > TIJUANA
# = T_IH_W_AA_N_AH
# < T_IY_JH_AAAN_AH
#
# > FURGERSON
# = F_ER_G_ER_S_AH_N
# < F_ER_G_EH_S_A___
#
# > JALAPENO
# = HH_AE_L_AH_P_IY_N_Y_OW
# < Y_AA_L_AA_P_EH_N_OW
#
# > RECORDING
# = R_AH_K_AO_R_D_IH_NG
# < R_IH_K_AO_R_D_IH_NG
#
# > ROCKETS
# = R_AA_K_AH_T_S
# < R_AA_K_AH_T_S
#
# > GRANSTROM
# = G_R_AE_N_S_T_R_AH_M
# < G_R_AE_N_S_T_R_AH_M_AH_M
#
# > BUTTERS
# = B_AH_T_ER_Z
# < B_AH_T_ER_Z
#
# > ANOMIE
# = AE_N_AH_M_IY
# < AA_N_AA_M_IY
#
# > NUTLETS
# = N_AH_T_L_AH_T_S
# < N_AH_T_L_AH_T_S

# %%
import pandas as pd

# %%
test_data = pd.read_csv("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/test.csv")
test_data.head()
# Out:
#    Id        Word
# 0   1     PITCHED
# 1   2  DISSOLVERS
# 2   3     SCRAWNY
# 3   4   BONENFANT
# 4   5     EXCEEDS

# %%
x_test = list(test_data['Word'])
print(len(x_test))
print(type(x_test))
print(x_test[:10])
print(x_test[-10:])
# Out:
# 41597
# <class 'list'>
# ['PITCHED', 'DISSOLVERS', 'SCRAWNY', 'BONENFANT', 'EXCEEDS', 'BARTNICKI', 'BUTE', 'CAPITULATE', 'STEAM', 'INVESTCORP']
# ['HUPFER', 'LEATHERMAN', 'LUPATKIN', 'ELABORATELY', 'ARRUPE', 'INOCULATION', 'UNTO', 'SCOGIN', 'HESSION', 'TARNOWSKI']

# %%
print(x_test[0])
# Out:
# PITCHED

# %%
y_test = []

# %%
y_test = predict(encoder1, attn_decoder1, x_test)
# Out:
# Progress: 0 / 41597
# Progress: 1000 / 41597
# Progress: 2000 / 41597
# Progress: 3000 / 41597
# Progress: 4000 / 41597
# Progress: 5000 / 41597
# Progress: 6000 / 41597
# Progress: 7000 / 41597
# Progress: 8000 / 41597
# Progress: 9000 / 41597
# Progress: 10000 / 41597
# Progress: 11000 / 41597
# Progress: 12000 / 41597
# Progress: 13000 / 41597
# Progress: 14000 / 41597
# Progress: 15000 / 41597
# Progress: 16000 / 41597
# Progress: 17000 / 41597
# Progress: 18000 / 41597
# Progress: 19000 / 41597
# Progress: 20000 / 41597
# Progress: 21000 / 41597
# Progress: 22000 / 41597
# Progress: 23000 / 41597
# Progress: 24000 / 41597
# Progress: 25000 / 41597
# Progress: 26000 / 41597
# Progress: 27000 / 41597
# Progress: 28000 / 41597
# Progress: 29000 / 41597
# Progress: 30000 / 41597
# Progress: 31000 / 41597
# Progress: 32000 / 41597
# Progress: 33000 / 41597
# Progress: 34000 / 41597
# Progress: 35000 / 41597
# Progress: 36000 / 41597
# Progress: 37000 / 41597
# Progress: 38000 / 41597
# Progress: 39000 / 41597
# Progress: 40000 / 41597
# Progress: 41000 / 41597
# Finished!!!

# %%
for i in range(len(y_test)):
    y_test[i] = y_test[i][:-1]

# %%
print(y_test[:10])
# Out:
# ['P_IH_CH_T', 'D_AY_S_AH_L_V_ER_Z', 'S_K_R_AO_N_IY', 'B_AH_N_IH_N_F_AE_N_T', 'EH_K_S_K_K_K_K_S_IH_Z', 'B_AA_R_T_N_N_IH_K_IY', 'B_UW_T', 'K_AE_P_IH_T_AH_L_EY_T', 'S_T_EH_M', 'IH_N_AH_S_T_AH_S_T_AH_P_T']

# %%
submission = pd.read_csv("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/test.csv")
submission['Word'] = y_test

# %%
print(submission.head())
# Out:
#    Id                   Word
# 0   1              P_IH_CH_T
# 1   2     D_AY_S_AH_L_V_ER_Z
# 2   3          S_K_R_AO_N_IY
# 3   4   B_AH_N_IH_N_F_AE_N_T
# 4   5  EH_K_S_K_K_K_K_S_IH_Z

# %%
submission.to_csv("/home/pavel/MyDocs/MachineLearning/Yandex_ML_project/lecture4/Kaggle_phonetics/submission_baseline_tf=0.5_no_.csv")
